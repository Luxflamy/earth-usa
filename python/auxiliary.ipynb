# %%
import pandas as pd
import os
import glob
from collections import Counter

directory_path = "./cleaned_data/"

csv_files = glob.glob(os.path.join(directory_path, "*.csv"))

origin_iata_counter = Counter()


for file_path in csv_files:
    try:
        file_name = os.path.basename(file_path)
        print(f"Reading: {file_name}")


        chunk_size = 500000

        for chunk in pd.read_csv(file_path, usecols=["ORIGIN_IATA"], chunksize=chunk_size):
            value_counts = chunk["ORIGIN_IATA"].value_counts().to_dict()
            origin_iata_counter.update(value_counts)

        print(f"{file_name} finished reading")

    except Exception as e:
        print(f"Error in reading {file_path}: {e}")

# 获取不同ORIGIN_IATA的总数
total_unique_iata = len(origin_iata_counter)
print(f"\n Find {total_unique_iata} distinct IATA codes")

# 获取出现次数最多的前100个机场
top_100_airports = origin_iata_counter.most_common(100)

# 打印结果
for i, (iata, count) in enumerate(top_100_airports, 1):
    print(f"{i}\t{iata}\t{count:,}")

result_df = pd.DataFrame(top_100_airports, columns=['ORIGIN_IATA', 'Times'])
result_df.index = result_df.index + 1
result_df.index.name = 'Rank'
result_df.to_csv("top_100_airports.csv")

print("\nSaved in top_100_airports.csv")
# Out:
# Reading: August2021.csv
# August2021.csv finished reading
# Reading: August2022.csv
# August2022.csv finished reading
# Reading: August2023.csv
# August2023.csv finished reading
# Reading: August2024.csv
# August2024.csv finished reading
# Reading: July2021.csv
# July2021.csv finished reading
# Reading: July2022.csv
# July2022.csv finished reading
# Reading: July2023.csv
# July2023.csv finished reading
# Reading: July2024.csv
# July2024.csv finished reading
# Reading: June2021.csv
# June2021.csv finished reading
# Reading: June2022.csv
# June2022.csv finished reading
# Reading: June2023.csv
# June2023.csv finished reading
# Reading: June2024.csv
# June2024.csv finished reading
# Reading: May2021.csv
# May2021.csv finished reading
# Reading: May2022.csv
# May2022.csv finished reading
# Reading: May2023.csv
# May2023.csv finished reading
# Reading: May2024.csv
# May2024.csv finished reading
#
#  Find 378 distinct IATA codes
# 1	ATL	457,121
# 2	ORD	429,876
# 3	DFW	414,896
# 4	DEN	411,220
# 5	CLT	323,043
# 6	LAX	270,765
# 7	SEA	261,944
# 8	LAS	241,505
# 9	PHX	231,414
# 10	IAH	219,698
# 11	MCO	203,573
# 12	LGA	198,886
# 13	EWR	185,000
# 14	BOS	182,177
# 15	DTW	182,153
# 16	MSP	176,945
# 17	DCA	176,042
# 18	SFO	175,127
# 19	JFK	165,581
# 20	PHL	160,753
# 21	SLC	159,234
# 22	MIA	137,371
# 23	BNA	127,193
# 24	BWI	126,397
# 25	SAN	121,962
# 26	FLL	116,908
# 27	AUS	115,842
# 28	MDW	113,666
# 29	IAD	107,323
# 30	TPA	97,235
# 31	DAL	93,970
# 32	PDX	91,915
# 33	STL	87,288
# 34	HNL	79,551
# 35	RDU	78,670
# 36	SMF	74,206
# 37	HOU	73,554
# 38	SJC	69,445
# 39	MCI	65,907
# 40	MSY	63,657
# 41	OAK	61,273
# 42	IND	60,851
# 43	SNA	60,199
# 44	PIT	57,755
# 45	CVG	56,761
# 46	CLE	56,478
# 47	CMH	55,231
# 48	SAT	51,025
# 49	SJU	47,567
# 50	OGG	40,818
# 51	RSW	40,167
# 52	JAX	39,570
# 53	BUR	38,349
# 54	MKE	38,199
# 55	CHS	37,885
# 56	BOI	36,770
# 57	ANC	35,925
# 58	SDF	34,633
# 59	ONT	33,440
# 60	MEM	32,180
# 61	RIC	31,892
# 62	OMA	31,699
# 63	BDL	31,627
# 64	ORF	31,587
# 65	OKC	31,292
# 66	ABQ	30,849
# 67	MYR	30,530
# 68	BUF	30,357
# 69	RNO	30,185
# 70	GEG	29,897
# 71	PBI	29,842
# 72	SAV	28,895
# 73	GRR	24,995
# 74	ELP	24,907
# 75	TYS	24,659
# 76	TUL	24,194
# 77	BHM	23,164
# 78	KOA	22,962
# 79	PVD	21,628
# 80	DSM	21,506
# 81	TUS	21,427
# 82	LIH	21,194
# 83	LGB	20,882
# 84	ROC	20,695
# 85	SYR	20,662
# 86	PNS	20,584
# 87	GSP	20,521
# 88	ALB	20,300
# 89	PWM	19,515
# 90	SRQ	19,045
# 91	LIT	18,617
# 92	AVL	17,913
# 93	COS	17,845
# 94	VPS	17,561
# 95	XNA	17,493
# 96	GSO	17,421
# 97	BZN	16,905
# 98	FAT	16,902
# 99	MSN	16,680
# 100	HPN	15,167
#
# Saved in top_100_airports.csv

# %%
import pandas as pd
import os
import glob
import re
from datetime import datetime
import numpy as np

# Define the path to the weather data folder
weather_data_path = 'weather_data/'  # Replace with the actual path

# Define output directory
output_dir = './cleaned_weather_data/'

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"Created output directory: {output_dir}")

# Get all CSV files
csv_files = glob.glob(os.path.join(weather_data_path, "*.csv"))

# Create a dictionary to organize files
airport_files = {}

# Parse filenames and organize files
for file_path in csv_files:
    file_name = os.path.basename(file_path)
    # Extract IATA code, year, and month from filename
    match = re.match(r'([A-Z]+)_(\d{4})_([A-Za-z]+)_(\d+)\.csv', file_name)
    if match:
        iata, year, month, station = match.groups()
        key = f"{iata}_{year}_{month}"

        if key not in airport_files:
            airport_files[key] = []

        airport_files[key].append(file_path)

# List of extreme weather columns to track
extreme_weather_cols = ['WT01', 'WT03', 'WT04', 'WT05', 'WT08', 'WT11']
# Add precipitation column
precipitation_col = 'PRCP'

# Process each airport-year-month combination
for key, file_list in airport_files.items():
    print(f"Processing {key}...")

    # Create empty DataFrame to store merged results
    result_df = None

    # Process all station files for this airport-year-month
    for file_path in file_list:
        try:
            # Read the CSV file
            df = pd.read_csv(file_path)

            # Ensure DATE column is in datetime format
            df['DATE'] = pd.to_datetime(df['DATE'])

            # Keep only date, extreme weather columns, and precipitation
            cols_to_keep = ['DATE'] + [col for col in extreme_weather_cols if col in df.columns]
            if precipitation_col in df.columns:
                cols_to_keep.append(precipitation_col)

            station_df = df[cols_to_keep].copy()

            # Handle missing values - replace NaN with 0 for extreme weather
            for col in extreme_weather_cols:
                if col in station_df.columns:
                    station_df[col] = station_df[col].fillna(0).astype(int)
                else:
                    station_df[col] = 0

            # Initialize result_df if it's empty
            if result_df is None:
                result_df = station_df
            else:
                # Merge data, taking maximum values for extreme weather (any station reporting counts as occurrence)
                result_df = pd.merge(result_df, station_df, on='DATE', how='outer', suffixes=('', f'_{file_path}'))

                # Process merged extreme weather columns
                for col in extreme_weather_cols:
                    # Find all columns related to this weather phenomenon
                    related_cols = [c for c in result_df.columns if c.startswith(col) and (c == col or c.startswith(f"{col}_"))]

                    if len(related_cols) > 1:
                        # Calculate if any station reported extreme weather
                        result_df[col] = result_df[related_cols].max(axis=1).fillna(0).astype(int)

                        # Remove temporary columns
                        for temp_col in related_cols:
                            if temp_col != col:
                                result_df = result_df.drop(columns=[temp_col])

        except Exception as e:
            print(f"Error processing file {file_path}: {e}")

    # If no valid data was found, continue to next key
    if result_df is None:
        print(f"Warning: No valid data for {key}")
        continue

    # Process precipitation column after all files are merged
    prcp_cols = [c for c in result_df.columns if c == precipitation_col or c.startswith(f"{precipitation_col}_")]

    if prcp_cols:
        # Custom function to calculate average precipitation
        # Only include positive values in the average calculation
        def avg_positive_prcp(row):
            # Get all precipitation values from the row
            values = [row[col] for col in prcp_cols]
            # Filter out NaN values
            values = [v for v in values if pd.notnull(v)]
            # Filter out zero values (only include positive precipitation)
            positive_values = [v for v in values if v > 0]

            # If there are positive values, return their average
            if positive_values:
                return sum(positive_values) / len(positive_values)
            # If there are valid measurements but all are zero, return 0
            elif values:
                return 0
            # If no valid data, return NaN
            else:
                return np.nan

        # Apply the custom function to calculate average precipitation
        result_df[precipitation_col] = result_df.apply(avg_positive_prcp, axis=1)

        # Remove temporary precipitation columns
        for temp_col in prcp_cols:
            if temp_col != precipitation_col:
                result_df = result_df.drop(columns=[temp_col])

    # Reorganize results
    # Keep only DATE, extreme weather columns, and precipitation
    final_cols = ['DATE'] + extreme_weather_cols
    if precipitation_col in result_df.columns:
        final_cols.append(precipitation_col)

    result_df = result_df[final_cols].copy()

    # Add an EXTREME_WEATHER column indicating presence of any extreme weather phenomenon
    result_df['EXTREME_WEATHER'] = result_df[extreme_weather_cols].max(axis=1)

    # Sort by date
    result_df = result_df.sort_values('DATE')

    # Save results to CSV file in the output directory
    output_file = os.path.join(output_dir, f"{key}.csv")
    result_df.to_csv(output_file, index=False)
    print(f"Results saved to {output_file}")

print("Processing complete!")
# Out:
# Created output directory: ./cleaned_weather_data/
# Processing ABI_2021_Aug...
# Results saved to ./cleaned_weather_data/ABI_2021_Aug.csv
# Processing ABI_2021_Jul...
# Results saved to ./cleaned_weather_data/ABI_2021_Jul.csv
# Processing ABI_2021_Jun...
# Results saved to ./cleaned_weather_data/ABI_2021_Jun.csv
# Processing ABI_2021_May...
# Results saved to ./cleaned_weather_data/ABI_2021_May.csv
# Processing ABI_2022_Aug...
# Results saved to ./cleaned_weather_data/ABI_2022_Aug.csv
# Processing ABI_2022_Jul...
# Results saved to ./cleaned_weather_data/ABI_2022_Jul.csv
# Processing ABI_2022_Jun...
# Results saved to ./cleaned_weather_data/ABI_2022_Jun.csv
# Processing ABI_2022_May...
# Results saved to ./cleaned_weather_data/ABI_2022_May.csv
# Processing ABI_2023_Aug...
# Results saved to ./cleaned_weather_data/ABI_2023_Aug.csv
# Processing ABI_2023_Jul...
# Results saved to ./cleaned_weather_data/ABI_2023_Jul.csv
# Processing ABI_2023_Jun...
# Results saved to ./cleaned_weather_data/ABI_2023_Jun.csv
# Processing ABI_2023_May...
# Results saved to ./cleaned_weather_data/ABI_2023_May.csv
# Processing ABI_2024_Aug...
# Results saved to ./cleaned_weather_data/ABI_2024_Aug.csv
# Processing ABI_2024_Jul...
# Results saved to ./cleaned_weather_data/ABI_2024_Jul.csv
# Processing ABI_2024_Jun...
# Results saved to ./cleaned_weather_data/ABI_2024_Jun.csv
# Processing ABI_2024_May...
# Results saved to ./cleaned_weather_data/ABI_2024_May.csv
# Processing ABQ_2021_Aug...
# Results saved to ./cleaned_weather_data/ABQ_2021_Aug.csv
# Processing ABQ_2021_Jul...
# Results saved to ./cleaned_weather_data/ABQ_2021_Jul.csv
# Processing ABQ_2021_Jun...
# Results saved to ./cleaned_weather_data/ABQ_2021_Jun.csv
# Processing ABQ_2021_May...
# Results saved to ./cleaned_weather_data/ABQ_2021_May.csv
# Processing ABQ_2022_Aug...
# Results saved to ./cleaned_weather_data/ABQ_2022_Aug.csv
# Processing ABQ_2022_Jul...
# Results saved to ./cleaned_weather_data/ABQ_2022_Jul.csv
# Processing ABQ_2022_Jun...
# Results saved to ./cleaned_weather_data/ABQ_2022_Jun.csv
# Processing ABQ_2022_May...
# Results saved to ./cleaned_weather_data/ABQ_2022_May.csv
# Processing ABQ_2023_Aug...
# Results saved to ./cleaned_weather_data/ABQ_2023_Aug.csv
# Processing ABQ_2023_Jul...
# Results saved to ./cleaned_weather_data/ABQ_2023_Jul.csv
# Processing ABQ_2023_Jun...
# Results saved to ./cleaned_weather_data/ABQ_2023_Jun.csv
# Processing ABQ_2023_May...
# Results saved to ./cleaned_weather_data/ABQ_2023_May.csv
# Processing ABQ_2024_Aug...
# Results saved to ./cleaned_weather_data/ABQ_2024_Aug.csv
# Processing ABQ_2024_Jul...
# Results saved to ./cleaned_weather_data/ABQ_2024_Jul.csv
# Processing ABQ_2024_Jun...
# Results saved to ./cleaned_weather_data/ABQ_2024_Jun.csv
# Processing ABQ_2024_May...
# Results saved to ./cleaned_weather_data/ABQ_2024_May.csv
# Processing ABY_2021_Aug...
# Results saved to ./cleaned_weather_data/ABY_2021_Aug.csv
# Processing ABY_2021_Jul...
# Results saved to ./cleaned_weather_data/ABY_2021_Jul.csv
# Processing ABY_2021_Jun...
# Results saved to ./cleaned_weather_data/ABY_2021_Jun.csv
# Processing ABY_2021_May...
# Results saved to ./cleaned_weather_data/ABY_2021_May.csv
# Processing ABY_2022_Aug...
# Results saved to ./cleaned_weather_data/ABY_2022_Aug.csv
# Processing ABY_2022_Jul...
# Results saved to ./cleaned_weather_data/ABY_2022_Jul.csv
# Processing ABY_2022_Jun...
# Results saved to ./cleaned_weather_data/ABY_2022_Jun.csv
# Processing ABY_2022_May...
# Results saved to ./cleaned_weather_data/ABY_2022_May.csv
# Processing ABY_2023_Aug...
# Results saved to ./cleaned_weather_data/ABY_2023_Aug.csv
# Processing ABY_2023_Jul...
# Results saved to ./cleaned_weather_data/ABY_2023_Jul.csv
# Processing ABY_2023_Jun...
# Results saved to ./cleaned_weather_data/ABY_2023_Jun.csv
# Processing ABY_2023_May...
# Results saved to ./cleaned_weather_data/ABY_2023_May.csv
# Processing ABY_2024_Aug...
# Results saved to ./cleaned_weather_data/ABY_2024_Aug.csv
# Processing ABY_2024_Jul...
# Results saved to ./cleaned_weather_data/ABY_2024_Jul.csv
# Processing ABY_2024_Jun...
# Results saved to ./cleaned_weather_data/ABY_2024_Jun.csv
# Processing ABY_2024_May...
# Results saved to ./cleaned_weather_data/ABY_2024_May.csv
# Processing ACK_2021_Aug...
# Results saved to ./cleaned_weather_data/ACK_2021_Aug.csv
# Processing ACK_2021_Jul...
# Results saved to ./cleaned_weather_data/ACK_2021_Jul.csv
# Processing ACK_2021_Jun...
# Results saved to ./cleaned_weather_data/ACK_2021_Jun.csv
# Processing ACK_2021_May...
# Results saved to ./cleaned_weather_data/ACK_2021_May.csv
# Processing ACK_2022_Aug...
# Results saved to ./cleaned_weather_data/ACK_2022_Aug.csv
# Processing ACK_2022_Jul...
# Results saved to ./cleaned_weather_data/ACK_2022_Jul.csv
# Processing ACK_2022_Jun...
# Results saved to ./cleaned_weather_data/ACK_2022_Jun.csv
# Processing ACK_2022_May...
# Results saved to ./cleaned_weather_data/ACK_2022_May.csv
# Processing ACK_2023_Aug...
# Results saved to ./cleaned_weather_data/ACK_2023_Aug.csv
# Processing ACK_2023_Jul...
# Results saved to ./cleaned_weather_data/ACK_2023_Jul.csv
# Processing ACK_2023_Jun...
# Results saved to ./cleaned_weather_data/ACK_2023_Jun.csv
# Processing ACK_2023_May...
# Results saved to ./cleaned_weather_data/ACK_2023_May.csv
# Processing ACK_2024_Aug...
# Results saved to ./cleaned_weather_data/ACK_2024_Aug.csv
# Processing ACK_2024_Jul...
# Results saved to ./cleaned_weather_data/ACK_2024_Jul.csv
# Processing ACK_2024_Jun...
# Results saved to ./cleaned_weather_data/ACK_2024_Jun.csv
# Processing ACK_2024_May...
# Results saved to ./cleaned_weather_data/ACK_2024_May.csv
# Processing ACT_2021_Aug...
# Results saved to ./cleaned_weather_data/ACT_2021_Aug.csv
# Processing ACT_2021_Jul...
# Results saved to ./cleaned_weather_data/ACT_2021_Jul.csv
# Processing ACT_2021_Jun...
# Results saved to ./cleaned_weather_data/ACT_2021_Jun.csv
# Processing ACT_2021_May...
# Results saved to ./cleaned_weather_data/ACT_2021_May.csv
# Processing ACT_2022_Aug...
# Results saved to ./cleaned_weather_data/ACT_2022_Aug.csv
# Processing ACT_2022_Jul...
# Results saved to ./cleaned_weather_data/ACT_2022_Jul.csv
# Processing ACT_2022_Jun...
# Results saved to ./cleaned_weather_data/ACT_2022_Jun.csv
# Processing ACT_2022_May...
# Results saved to ./cleaned_weather_data/ACT_2022_May.csv
# Processing ACT_2023_Aug...
# Results saved to ./cleaned_weather_data/ACT_2023_Aug.csv
# Processing ACT_2023_Jul...
# Results saved to ./cleaned_weather_data/ACT_2023_Jul.csv
# Processing ACT_2023_Jun...
# Results saved to ./cleaned_weather_data/ACT_2023_Jun.csv
# Processing ACT_2023_May...
# Results saved to ./cleaned_weather_data/ACT_2023_May.csv
# Processing ACT_2024_Aug...
# Results saved to ./cleaned_weather_data/ACT_2024_Aug.csv
# Processing ACT_2024_Jul...
# Results saved to ./cleaned_weather_data/ACT_2024_Jul.csv
# Processing ACT_2024_Jun...
# Results saved to ./cleaned_weather_data/ACT_2024_Jun.csv
# Processing ACT_2024_May...
# Results saved to ./cleaned_weather_data/ACT_2024_May.csv
# Processing ACY_2021_Aug...
# Results saved to ./cleaned_weather_data/ACY_2021_Aug.csv
# Processing ACY_2021_Jul...
# Results saved to ./cleaned_weather_data/ACY_2021_Jul.csv
# Processing ACY_2021_Jun...
# Results saved to ./cleaned_weather_data/ACY_2021_Jun.csv
# Processing ACY_2021_May...
# Results saved to ./cleaned_weather_data/ACY_2021_May.csv
# Processing ACY_2022_Aug...
# Results saved to ./cleaned_weather_data/ACY_2022_Aug.csv
# Processing ACY_2022_Jul...
# Results saved to ./cleaned_weather_data/ACY_2022_Jul.csv
# Processing ACY_2022_Jun...
# Results saved to ./cleaned_weather_data/ACY_2022_Jun.csv
# Processing ACY_2022_May...
# Results saved to ./cleaned_weather_data/ACY_2022_May.csv
# Processing ACY_2023_Aug...
# Results saved to ./cleaned_weather_data/ACY_2023_Aug.csv
# Processing ACY_2023_Jul...
# Results saved to ./cleaned_weather_data/ACY_2023_Jul.csv
# Processing ACY_2023_Jun...
# Results saved to ./cleaned_weather_data/ACY_2023_Jun.csv
# Processing ACY_2023_May...
# Results saved to ./cleaned_weather_data/ACY_2023_May.csv
# Processing ACY_2024_Aug...
# Results saved to ./cleaned_weather_data/ACY_2024_Aug.csv
# Processing ACY_2024_Jul...
# Results saved to ./cleaned_weather_data/ACY_2024_Jul.csv
# Processing ACY_2024_Jun...
# Results saved to ./cleaned_weather_data/ACY_2024_Jun.csv
# Processing ACY_2024_May...
# Results saved to ./cleaned_weather_data/ACY_2024_May.csv
# Processing ADK_2021_Aug...
# Results saved to ./cleaned_weather_data/ADK_2021_Aug.csv
# Processing ADK_2021_Jul...
# Results saved to ./cleaned_weather_data/ADK_2021_Jul.csv
# Processing ADK_2021_Jun...
# Results saved to ./cleaned_weather_data/ADK_2021_Jun.csv
# Processing ADK_2021_May...
# Results saved to ./cleaned_weather_data/ADK_2021_May.csv
# Processing ADK_2022_Aug...
# Results saved to ./cleaned_weather_data/ADK_2022_Aug.csv
# Processing ADK_2022_Jul...
# Results saved to ./cleaned_weather_data/ADK_2022_Jul.csv
# Processing ADK_2022_Jun...
# Results saved to ./cleaned_weather_data/ADK_2022_Jun.csv
# Processing ADK_2022_May...
# Results saved to ./cleaned_weather_data/ADK_2022_May.csv
# Processing ADK_2023_Aug...
# Results saved to ./cleaned_weather_data/ADK_2023_Aug.csv
# Processing ADK_2023_Jul...
# Results saved to ./cleaned_weather_data/ADK_2023_Jul.csv
# Processing ADK_2023_Jun...
# Results saved to ./cleaned_weather_data/ADK_2023_Jun.csv
# Processing ADK_2023_May...
# Results saved to ./cleaned_weather_data/ADK_2023_May.csv
# Processing ADK_2024_Aug...
# Results saved to ./cleaned_weather_data/ADK_2024_Aug.csv
# Processing ADK_2024_Jul...
# Results saved to ./cleaned_weather_data/ADK_2024_Jul.csv
# Processing ADK_2024_Jun...
# Results saved to ./cleaned_weather_data/ADK_2024_Jun.csv
# Processing ADK_2024_May...
# Results saved to ./cleaned_weather_data/ADK_2024_May.csv
# Processing ADQ_2021_Aug...
# Results saved to ./cleaned_weather_data/ADQ_2021_Aug.csv
# Processing ADQ_2021_Jul...
# Results saved to ./cleaned_weather_data/ADQ_2021_Jul.csv
# Processing ADQ_2021_Jun...
# Results saved to ./cleaned_weather_data/ADQ_2021_Jun.csv
# Processing ADQ_2021_May...
# Results saved to ./cleaned_weather_data/ADQ_2021_May.csv
# Processing ADQ_2022_Aug...
# Results saved to ./cleaned_weather_data/ADQ_2022_Aug.csv
# Processing ADQ_2022_Jul...
# Results saved to ./cleaned_weather_data/ADQ_2022_Jul.csv
# Processing ADQ_2022_Jun...
# Results saved to ./cleaned_weather_data/ADQ_2022_Jun.csv
# Processing ADQ_2022_May...
# Results saved to ./cleaned_weather_data/ADQ_2022_May.csv
# Processing ADQ_2023_Aug...
# Results saved to ./cleaned_weather_data/ADQ_2023_Aug.csv
# Processing ADQ_2023_Jul...
# Results saved to ./cleaned_weather_data/ADQ_2023_Jul.csv
# Processing ADQ_2023_Jun...
# Results saved to ./cleaned_weather_data/ADQ_2023_Jun.csv
# Processing ADQ_2023_May...
# Results saved to ./cleaned_weather_data/ADQ_2023_May.csv
# Processing ADQ_2024_Aug...
# Results saved to ./cleaned_weather_data/ADQ_2024_Aug.csv
# Processing ADQ_2024_Jul...
# Results saved to ./cleaned_weather_data/ADQ_2024_Jul.csv
# Processing ADQ_2024_Jun...
# Results saved to ./cleaned_weather_data/ADQ_2024_Jun.csv
# Processing ADQ_2024_May...
# Results saved to ./cleaned_weather_data/ADQ_2024_May.csv
# Processing AEX_2021_Aug...
# Results saved to ./cleaned_weather_data/AEX_2021_Aug.csv
# Processing AEX_2021_Jul...
# Results saved to ./cleaned_weather_data/AEX_2021_Jul.csv
# Processing AEX_2021_Jun...
# Results saved to ./cleaned_weather_data/AEX_2021_Jun.csv
# Processing AEX_2021_May...
# Results saved to ./cleaned_weather_data/AEX_2021_May.csv
# Processing AEX_2022_Aug...
# Results saved to ./cleaned_weather_data/AEX_2022_Aug.csv
# Processing AEX_2022_Jul...
# Results saved to ./cleaned_weather_data/AEX_2022_Jul.csv
# Processing AEX_2022_Jun...
# Results saved to ./cleaned_weather_data/AEX_2022_Jun.csv
# Processing AEX_2022_May...
# Results saved to ./cleaned_weather_data/AEX_2022_May.csv
# Processing AEX_2023_Aug...
# Results saved to ./cleaned_weather_data/AEX_2023_Aug.csv
# Processing AEX_2023_Jul...
# Results saved to ./cleaned_weather_data/AEX_2023_Jul.csv
# Processing AEX_2023_Jun...
# Results saved to ./cleaned_weather_data/AEX_2023_Jun.csv
# Processing AEX_2023_May...
# Results saved to ./cleaned_weather_data/AEX_2023_May.csv
# Processing AEX_2024_Aug...
# Results saved to ./cleaned_weather_data/AEX_2024_Aug.csv
# Processing AEX_2024_Jul...
# Results saved to ./cleaned_weather_data/AEX_2024_Jul.csv
# Processing AEX_2024_Jun...
# Results saved to ./cleaned_weather_data/AEX_2024_Jun.csv
# Processing AEX_2024_May...
# Results saved to ./cleaned_weather_data/AEX_2024_May.csv
# Processing AGS_2021_Aug...
# Results saved to ./cleaned_weather_data/AGS_2021_Aug.csv
# Processing AGS_2021_Jul...
# Results saved to ./cleaned_weather_data/AGS_2021_Jul.csv
# Processing AGS_2021_Jun...
# Results saved to ./cleaned_weather_data/AGS_2021_Jun.csv
# Processing AGS_2021_May...
# Results saved to ./cleaned_weather_data/AGS_2021_May.csv
# Processing AGS_2022_Aug...
# Results saved to ./cleaned_weather_data/AGS_2022_Aug.csv
# Processing AGS_2022_Jul...
# Results saved to ./cleaned_weather_data/AGS_2022_Jul.csv
# Processing AGS_2022_Jun...
# Results saved to ./cleaned_weather_data/AGS_2022_Jun.csv
# Processing AGS_2022_May...
# Results saved to ./cleaned_weather_data/AGS_2022_May.csv
# Processing AGS_2023_Aug...
# Results saved to ./cleaned_weather_data/AGS_2023_Aug.csv
# Processing AGS_2023_Jul...
# Results saved to ./cleaned_weather_data/AGS_2023_Jul.csv
# Processing AGS_2023_Jun...
# Results saved to ./cleaned_weather_data/AGS_2023_Jun.csv
# Processing AGS_2023_May...
# Results saved to ./cleaned_weather_data/AGS_2023_May.csv
# Processing AGS_2024_Aug...
# Results saved to ./cleaned_weather_data/AGS_2024_Aug.csv
# Processing AGS_2024_Jul...
# Results saved to ./cleaned_weather_data/AGS_2024_Jul.csv
# Processing AGS_2024_Jun...
# Results saved to ./cleaned_weather_data/AGS_2024_Jun.csv
# Processing AGS_2024_May...
# Results saved to ./cleaned_weather_data/AGS_2024_May.csv
# Processing ALB_2021_Aug...
# Results saved to ./cleaned_weather_data/ALB_2021_Aug.csv
# Processing ALB_2021_Jul...
# Results saved to ./cleaned_weather_data/ALB_2021_Jul.csv
# Processing ALB_2021_Jun...
# Results saved to ./cleaned_weather_data/ALB_2021_Jun.csv
# Processing ALB_2021_May...
# Results saved to ./cleaned_weather_data/ALB_2021_May.csv
# Processing ALB_2022_Aug...
# Results saved to ./cleaned_weather_data/ALB_2022_Aug.csv
# Processing ALB_2022_Jul...
# Results saved to ./cleaned_weather_data/ALB_2022_Jul.csv
# Processing ALB_2022_Jun...
# Results saved to ./cleaned_weather_data/ALB_2022_Jun.csv
# Processing ALB_2022_May...
# Results saved to ./cleaned_weather_data/ALB_2022_May.csv
# Processing ALB_2023_Aug...
# Results saved to ./cleaned_weather_data/ALB_2023_Aug.csv
# Processing ALB_2023_Jul...
# Results saved to ./cleaned_weather_data/ALB_2023_Jul.csv
# Processing ALB_2023_Jun...
# Results saved to ./cleaned_weather_data/ALB_2023_Jun.csv
# Processing ALB_2023_May...
# Results saved to ./cleaned_weather_data/ALB_2023_May.csv
# Processing ALB_2024_Aug...
# Results saved to ./cleaned_weather_data/ALB_2024_Aug.csv
# Processing ALB_2024_Jul...
# Results saved to ./cleaned_weather_data/ALB_2024_Jul.csv
# Processing ALB_2024_Jun...
# Results saved to ./cleaned_weather_data/ALB_2024_Jun.csv
# Processing ALB_2024_May...
# Results saved to ./cleaned_weather_data/ALB_2024_May.csv
# Processing ALO_2021_Aug...
# Results saved to ./cleaned_weather_data/ALO_2021_Aug.csv
# Processing ALO_2021_Jul...
# Results saved to ./cleaned_weather_data/ALO_2021_Jul.csv
# Processing ALO_2021_Jun...
# Results saved to ./cleaned_weather_data/ALO_2021_Jun.csv
# Processing ALO_2021_May...
# Results saved to ./cleaned_weather_data/ALO_2021_May.csv
# Processing ALO_2022_Aug...
# Results saved to ./cleaned_weather_data/ALO_2022_Aug.csv
# Processing ALO_2022_Jul...
# Results saved to ./cleaned_weather_data/ALO_2022_Jul.csv
# Processing ALO_2022_Jun...
# Results saved to ./cleaned_weather_data/ALO_2022_Jun.csv
# Processing ALO_2022_May...
# Results saved to ./cleaned_weather_data/ALO_2022_May.csv
# Processing ALO_2023_Aug...
# Results saved to ./cleaned_weather_data/ALO_2023_Aug.csv
# Processing ALO_2023_Jul...
# Results saved to ./cleaned_weather_data/ALO_2023_Jul.csv
# Processing ALO_2023_Jun...
# Results saved to ./cleaned_weather_data/ALO_2023_Jun.csv
# Processing ALO_2023_May...
# Results saved to ./cleaned_weather_data/ALO_2023_May.csv
# Processing ALO_2024_Aug...
# Results saved to ./cleaned_weather_data/ALO_2024_Aug.csv
# Processing ALO_2024_Jul...
# Results saved to ./cleaned_weather_data/ALO_2024_Jul.csv
# Processing ALO_2024_Jun...
# Results saved to ./cleaned_weather_data/ALO_2024_Jun.csv
# Processing ALO_2024_May...
# Results saved to ./cleaned_weather_data/ALO_2024_May.csv
# Processing ALW_2021_Aug...
# Results saved to ./cleaned_weather_data/ALW_2021_Aug.csv
# Processing ALW_2021_Jul...
# Results saved to ./cleaned_weather_data/ALW_2021_Jul.csv
# Processing ALW_2021_Jun...
# Results saved to ./cleaned_weather_data/ALW_2021_Jun.csv
# Processing ALW_2021_May...
# Results saved to ./cleaned_weather_data/ALW_2021_May.csv
# Processing ALW_2022_Aug...
# Results saved to ./cleaned_weather_data/ALW_2022_Aug.csv
# Processing ALW_2022_Jul...
# Results saved to ./cleaned_weather_data/ALW_2022_Jul.csv
# Processing ALW_2022_Jun...
# Results saved to ./cleaned_weather_data/ALW_2022_Jun.csv
# Processing ALW_2022_May...
# Results saved to ./cleaned_weather_data/ALW_2022_May.csv
# Processing ALW_2023_Aug...
# Results saved to ./cleaned_weather_data/ALW_2023_Aug.csv
# Processing ALW_2023_Jul...
# Results saved to ./cleaned_weather_data/ALW_2023_Jul.csv
# Processing ALW_2023_Jun...
# Results saved to ./cleaned_weather_data/ALW_2023_Jun.csv
# Processing ALW_2023_May...
# Results saved to ./cleaned_weather_data/ALW_2023_May.csv
# Processing ALW_2024_Aug...
# Results saved to ./cleaned_weather_data/ALW_2024_Aug.csv
# Processing ALW_2024_Jul...
# Results saved to ./cleaned_weather_data/ALW_2024_Jul.csv
# Processing ALW_2024_Jun...
# Results saved to ./cleaned_weather_data/ALW_2024_Jun.csv
# Processing ALW_2024_May...
# Results saved to ./cleaned_weather_data/ALW_2024_May.csv
# Processing ANC_2021_Aug...
# Results saved to ./cleaned_weather_data/ANC_2021_Aug.csv
# Processing ANC_2021_Jul...
# Results saved to ./cleaned_weather_data/ANC_2021_Jul.csv
# Processing ANC_2021_Jun...
# Results saved to ./cleaned_weather_data/ANC_2021_Jun.csv
# Processing ANC_2021_May...
# Results saved to ./cleaned_weather_data/ANC_2021_May.csv
# Processing ANC_2022_Aug...
# Results saved to ./cleaned_weather_data/ANC_2022_Aug.csv
# Processing ANC_2022_Jul...
# Results saved to ./cleaned_weather_data/ANC_2022_Jul.csv
# Processing ANC_2022_Jun...
# Results saved to ./cleaned_weather_data/ANC_2022_Jun.csv
# Processing ANC_2022_May...
# Results saved to ./cleaned_weather_data/ANC_2022_May.csv
# Processing ANC_2023_Aug...
# Results saved to ./cleaned_weather_data/ANC_2023_Aug.csv
# Processing ANC_2023_Jul...
# Results saved to ./cleaned_weather_data/ANC_2023_Jul.csv
# Processing ANC_2023_Jun...
# Results saved to ./cleaned_weather_data/ANC_2023_Jun.csv
# Processing ANC_2023_May...
# Results saved to ./cleaned_weather_data/ANC_2023_May.csv
# Processing ANC_2024_Aug...
# Results saved to ./cleaned_weather_data/ANC_2024_Aug.csv
# Processing ANC_2024_Jul...
# Results saved to ./cleaned_weather_data/ANC_2024_Jul.csv
# Processing ANC_2024_Jun...
# Results saved to ./cleaned_weather_data/ANC_2024_Jun.csv
# Processing ANC_2024_May...
# Results saved to ./cleaned_weather_data/ANC_2024_May.csv
# Processing APN_2021_Aug...
# Results saved to ./cleaned_weather_data/APN_2021_Aug.csv
# Processing APN_2021_Jul...
# Results saved to ./cleaned_weather_data/APN_2021_Jul.csv
# Processing APN_2021_Jun...
# Results saved to ./cleaned_weather_data/APN_2021_Jun.csv
# Processing APN_2021_May...
# Results saved to ./cleaned_weather_data/APN_2021_May.csv
# Processing APN_2022_Aug...
# Results saved to ./cleaned_weather_data/APN_2022_Aug.csv
# Processing APN_2022_Jul...
# Results saved to ./cleaned_weather_data/APN_2022_Jul.csv
# Processing APN_2022_Jun...
# Results saved to ./cleaned_weather_data/APN_2022_Jun.csv
# Processing APN_2022_May...
# Results saved to ./cleaned_weather_data/APN_2022_May.csv
# Processing APN_2023_Aug...
# Results saved to ./cleaned_weather_data/APN_2023_Aug.csv
# Processing APN_2023_Jul...
# Results saved to ./cleaned_weather_data/APN_2023_Jul.csv
# Processing APN_2023_Jun...
# Results saved to ./cleaned_weather_data/APN_2023_Jun.csv
# Processing APN_2023_May...
# Results saved to ./cleaned_weather_data/APN_2023_May.csv
# Processing APN_2024_Aug...
# Results saved to ./cleaned_weather_data/APN_2024_Aug.csv
# Processing APN_2024_Jul...
# Results saved to ./cleaned_weather_data/APN_2024_Jul.csv
# Processing APN_2024_Jun...
# Results saved to ./cleaned_weather_data/APN_2024_Jun.csv
# Processing APN_2024_May...
# Results saved to ./cleaned_weather_data/APN_2024_May.csv
# Processing ART_2021_Aug...
# Results saved to ./cleaned_weather_data/ART_2021_Aug.csv
# Processing ART_2021_Jul...
# Results saved to ./cleaned_weather_data/ART_2021_Jul.csv
# Processing ART_2021_Jun...
# Results saved to ./cleaned_weather_data/ART_2021_Jun.csv
# Processing ART_2021_May...
# Results saved to ./cleaned_weather_data/ART_2021_May.csv
# Processing ART_2022_Aug...
# Results saved to ./cleaned_weather_data/ART_2022_Aug.csv
# Processing ART_2022_Jul...
# Results saved to ./cleaned_weather_data/ART_2022_Jul.csv
# Processing ART_2022_Jun...
# Results saved to ./cleaned_weather_data/ART_2022_Jun.csv
# Processing ART_2022_May...
# Results saved to ./cleaned_weather_data/ART_2022_May.csv
# Processing ART_2023_Aug...
# Results saved to ./cleaned_weather_data/ART_2023_Aug.csv
# Processing ART_2023_Jul...
# Results saved to ./cleaned_weather_data/ART_2023_Jul.csv
# Processing ART_2023_Jun...
# Results saved to ./cleaned_weather_data/ART_2023_Jun.csv
# Processing ART_2023_May...
# Results saved to ./cleaned_weather_data/ART_2023_May.csv
# Processing ART_2024_Aug...
# Results saved to ./cleaned_weather_data/ART_2024_Aug.csv
# Processing ART_2024_Jul...
# Results saved to ./cleaned_weather_data/ART_2024_Jul.csv
# Processing ART_2024_Jun...
# Results saved to ./cleaned_weather_data/ART_2024_Jun.csv
# Processing ART_2024_May...
# Results saved to ./cleaned_weather_data/ART_2024_May.csv
# Processing ASE_2021_Aug...
# Results saved to ./cleaned_weather_data/ASE_2021_Aug.csv
# Processing ASE_2021_Jul...
# Results saved to ./cleaned_weather_data/ASE_2021_Jul.csv
# Processing ASE_2021_Jun...
# Results saved to ./cleaned_weather_data/ASE_2021_Jun.csv
# Processing ASE_2021_May...
# Results saved to ./cleaned_weather_data/ASE_2021_May.csv
# Processing ASE_2022_Aug...
# Results saved to ./cleaned_weather_data/ASE_2022_Aug.csv
# Processing ASE_2022_Jul...
# Results saved to ./cleaned_weather_data/ASE_2022_Jul.csv
# Processing ASE_2022_Jun...
# Results saved to ./cleaned_weather_data/ASE_2022_Jun.csv
# Processing ASE_2022_May...
# Results saved to ./cleaned_weather_data/ASE_2022_May.csv
# Processing ASE_2023_Aug...
# Results saved to ./cleaned_weather_data/ASE_2023_Aug.csv
# Processing ASE_2023_Jul...
# Results saved to ./cleaned_weather_data/ASE_2023_Jul.csv
# Processing ASE_2023_Jun...
# Results saved to ./cleaned_weather_data/ASE_2023_Jun.csv
# Processing ASE_2023_May...
# Results saved to ./cleaned_weather_data/ASE_2023_May.csv
# Processing ASE_2024_Aug...
# Results saved to ./cleaned_weather_data/ASE_2024_Aug.csv
# Processing ASE_2024_Jul...
# Results saved to ./cleaned_weather_data/ASE_2024_Jul.csv
# Processing ASE_2024_Jun...
# Results saved to ./cleaned_weather_data/ASE_2024_Jun.csv
# Processing ASE_2024_May...
# Results saved to ./cleaned_weather_data/ASE_2024_May.csv
# Processing ATL_2021_Aug...
# Results saved to ./cleaned_weather_data/ATL_2021_Aug.csv
# Processing ATL_2021_Jul...
# Results saved to ./cleaned_weather_data/ATL_2021_Jul.csv
# Processing ATL_2021_Jun...
# Results saved to ./cleaned_weather_data/ATL_2021_Jun.csv
# Processing ATL_2021_May...
# Results saved to ./cleaned_weather_data/ATL_2021_May.csv
# Processing ATL_2022_Aug...
# Results saved to ./cleaned_weather_data/ATL_2022_Aug.csv
# Processing ATL_2022_Jul...
# Results saved to ./cleaned_weather_data/ATL_2022_Jul.csv
# Processing ATL_2022_Jun...
# Results saved to ./cleaned_weather_data/ATL_2022_Jun.csv
# Processing ATL_2022_May...
# Results saved to ./cleaned_weather_data/ATL_2022_May.csv
# Processing ATL_2023_Aug...
# Results saved to ./cleaned_weather_data/ATL_2023_Aug.csv
# Processing ATL_2023_Jul...
# Results saved to ./cleaned_weather_data/ATL_2023_Jul.csv
# Processing ATL_2023_Jun...
# Results saved to ./cleaned_weather_data/ATL_2023_Jun.csv
# Processing ATL_2023_May...
# Results saved to ./cleaned_weather_data/ATL_2023_May.csv
# Processing ATL_2024_Aug...
# Results saved to ./cleaned_weather_data/ATL_2024_Aug.csv
# Processing ATL_2024_Jul...
# Results saved to ./cleaned_weather_data/ATL_2024_Jul.csv
# Processing ATL_2024_Jun...
# Results saved to ./cleaned_weather_data/ATL_2024_Jun.csv
# Processing ATL_2024_May...
# Results saved to ./cleaned_weather_data/ATL_2024_May.csv
# Processing ATW_2021_Aug...
# Results saved to ./cleaned_weather_data/ATW_2021_Aug.csv
# Processing ATW_2021_Jun...
# Results saved to ./cleaned_weather_data/ATW_2021_Jun.csv
# Processing ATW_2021_May...
# Results saved to ./cleaned_weather_data/ATW_2021_May.csv
# Processing ATW_2022_Aug...
# Results saved to ./cleaned_weather_data/ATW_2022_Aug.csv
# Processing ATW_2022_Jul...
# Results saved to ./cleaned_weather_data/ATW_2022_Jul.csv
# Processing ATW_2022_Jun...
# Results saved to ./cleaned_weather_data/ATW_2022_Jun.csv
# Processing ATW_2022_May...
# Results saved to ./cleaned_weather_data/ATW_2022_May.csv
# Processing ATW_2023_Jun...
# Results saved to ./cleaned_weather_data/ATW_2023_Jun.csv
# Processing ATW_2023_May...
# Results saved to ./cleaned_weather_data/ATW_2023_May.csv
# Processing ATW_2024_Aug...
# Results saved to ./cleaned_weather_data/ATW_2024_Aug.csv
# Processing ATW_2024_Jul...
# Results saved to ./cleaned_weather_data/ATW_2024_Jul.csv
# Processing ATW_2024_Jun...
# Results saved to ./cleaned_weather_data/ATW_2024_Jun.csv
# Processing ATW_2024_May...
# Results saved to ./cleaned_weather_data/ATW_2024_May.csv
# Processing ATY_2021_Aug...
# Results saved to ./cleaned_weather_data/ATY_2021_Aug.csv
# Processing ATY_2021_Jul...
# Results saved to ./cleaned_weather_data/ATY_2021_Jul.csv
# Processing ATY_2021_Jun...
# Results saved to ./cleaned_weather_data/ATY_2021_Jun.csv
# Processing ATY_2021_May...
# Results saved to ./cleaned_weather_data/ATY_2021_May.csv
# Processing ATY_2022_Aug...
# Results saved to ./cleaned_weather_data/ATY_2022_Aug.csv
# Processing ATY_2022_Jul...
# Results saved to ./cleaned_weather_data/ATY_2022_Jul.csv
# Processing ATY_2022_Jun...
# Results saved to ./cleaned_weather_data/ATY_2022_Jun.csv
# Processing ATY_2022_May...
# Results saved to ./cleaned_weather_data/ATY_2022_May.csv
# Processing ATY_2023_Aug...
# Results saved to ./cleaned_weather_data/ATY_2023_Aug.csv
# Processing ATY_2023_Jul...
# Results saved to ./cleaned_weather_data/ATY_2023_Jul.csv
# Processing ATY_2023_Jun...
# Results saved to ./cleaned_weather_data/ATY_2023_Jun.csv
# Processing ATY_2023_May...
# Results saved to ./cleaned_weather_data/ATY_2023_May.csv
# Processing ATY_2024_Aug...
# Results saved to ./cleaned_weather_data/ATY_2024_Aug.csv
# Processing ATY_2024_Jul...
# Results saved to ./cleaned_weather_data/ATY_2024_Jul.csv
# Processing ATY_2024_Jun...
# Results saved to ./cleaned_weather_data/ATY_2024_Jun.csv
# Processing ATY_2024_May...
# Results saved to ./cleaned_weather_data/ATY_2024_May.csv
# Processing AUS_2021_Aug...
# Results saved to ./cleaned_weather_data/AUS_2021_Aug.csv
# Processing AUS_2021_Jul...
# Results saved to ./cleaned_weather_data/AUS_2021_Jul.csv
# Processing AUS_2021_Jun...
# Results saved to ./cleaned_weather_data/AUS_2021_Jun.csv
# Processing AUS_2021_May...
# Results saved to ./cleaned_weather_data/AUS_2021_May.csv
# Processing AUS_2022_Aug...
# Results saved to ./cleaned_weather_data/AUS_2022_Aug.csv
# Processing AUS_2022_Jul...
# Results saved to ./cleaned_weather_data/AUS_2022_Jul.csv
# Processing AUS_2022_Jun...
# Results saved to ./cleaned_weather_data/AUS_2022_Jun.csv
# Processing AUS_2022_May...
# Results saved to ./cleaned_weather_data/AUS_2022_May.csv
# Processing AUS_2023_Aug...
# Results saved to ./cleaned_weather_data/AUS_2023_Aug.csv
# Processing AUS_2023_Jul...
# Results saved to ./cleaned_weather_data/AUS_2023_Jul.csv
# Processing AUS_2023_Jun...
# Results saved to ./cleaned_weather_data/AUS_2023_Jun.csv
# Processing AUS_2023_May...
# Results saved to ./cleaned_weather_data/AUS_2023_May.csv
# Processing AUS_2024_Aug...
# Results saved to ./cleaned_weather_data/AUS_2024_Aug.csv
# Processing AUS_2024_Jul...
# Results saved to ./cleaned_weather_data/AUS_2024_Jul.csv
# Processing AUS_2024_Jun...
# Results saved to ./cleaned_weather_data/AUS_2024_Jun.csv
# Processing AUS_2024_May...
# Results saved to ./cleaned_weather_data/AUS_2024_May.csv
# Processing AVL_2021_Aug...
# Results saved to ./cleaned_weather_data/AVL_2021_Aug.csv
# Processing AVL_2021_Jul...
# Results saved to ./cleaned_weather_data/AVL_2021_Jul.csv
# Processing AVL_2021_Jun...
# Results saved to ./cleaned_weather_data/AVL_2021_Jun.csv
# Processing AVL_2021_May...
# Results saved to ./cleaned_weather_data/AVL_2021_May.csv
# Processing AVL_2022_Aug...
# Results saved to ./cleaned_weather_data/AVL_2022_Aug.csv
# Processing AVL_2022_Jul...
# Results saved to ./cleaned_weather_data/AVL_2022_Jul.csv
# Processing AVL_2022_Jun...
# Results saved to ./cleaned_weather_data/AVL_2022_Jun.csv
# Processing AVL_2022_May...
# Results saved to ./cleaned_weather_data/AVL_2022_May.csv
# Processing AVL_2023_Aug...
# Results saved to ./cleaned_weather_data/AVL_2023_Aug.csv
# Processing AVL_2023_Jul...
# Results saved to ./cleaned_weather_data/AVL_2023_Jul.csv
# Processing AVL_2023_Jun...
# Results saved to ./cleaned_weather_data/AVL_2023_Jun.csv
# Processing AVL_2023_May...
# Results saved to ./cleaned_weather_data/AVL_2023_May.csv
# Processing AVL_2024_Aug...
# Results saved to ./cleaned_weather_data/AVL_2024_Aug.csv
# Processing AVL_2024_Jul...
# Results saved to ./cleaned_weather_data/AVL_2024_Jul.csv
# Processing AVL_2024_Jun...
# Results saved to ./cleaned_weather_data/AVL_2024_Jun.csv
# Processing AVL_2024_May...
# Results saved to ./cleaned_weather_data/AVL_2024_May.csv
# Processing AZA_2021_Aug...
# Results saved to ./cleaned_weather_data/AZA_2021_Aug.csv
# Processing AZA_2021_Jul...
# Results saved to ./cleaned_weather_data/AZA_2021_Jul.csv
# Processing AZA_2021_Jun...
# Results saved to ./cleaned_weather_data/AZA_2021_Jun.csv
# Processing AZA_2021_May...
# Results saved to ./cleaned_weather_data/AZA_2021_May.csv
# Processing AZA_2022_Aug...
# Results saved to ./cleaned_weather_data/AZA_2022_Aug.csv
# Processing AZA_2022_Jul...
# Results saved to ./cleaned_weather_data/AZA_2022_Jul.csv
# Processing AZA_2022_Jun...
# Results saved to ./cleaned_weather_data/AZA_2022_Jun.csv
# Processing AZA_2022_May...
# Results saved to ./cleaned_weather_data/AZA_2022_May.csv
# Processing AZA_2023_Aug...
# Results saved to ./cleaned_weather_data/AZA_2023_Aug.csv
# Processing AZA_2023_Jul...
# Results saved to ./cleaned_weather_data/AZA_2023_Jul.csv
# Processing AZA_2023_Jun...
# Results saved to ./cleaned_weather_data/AZA_2023_Jun.csv
# Processing AZA_2023_May...
# Results saved to ./cleaned_weather_data/AZA_2023_May.csv
# Processing AZA_2024_Aug...
# Results saved to ./cleaned_weather_data/AZA_2024_Aug.csv
# Processing AZA_2024_Jul...
# Results saved to ./cleaned_weather_data/AZA_2024_Jul.csv
# Processing AZA_2024_Jun...
# Results saved to ./cleaned_weather_data/AZA_2024_Jun.csv
# Processing AZA_2024_May...
# Results saved to ./cleaned_weather_data/AZA_2024_May.csv
# Processing AZO_2021_Aug...
# Results saved to ./cleaned_weather_data/AZO_2021_Aug.csv
# Processing AZO_2021_Jul...
# Results saved to ./cleaned_weather_data/AZO_2021_Jul.csv
# Processing AZO_2021_Jun...
# Results saved to ./cleaned_weather_data/AZO_2021_Jun.csv
# Processing AZO_2021_May...
# Results saved to ./cleaned_weather_data/AZO_2021_May.csv
# Processing AZO_2022_Aug...
# Results saved to ./cleaned_weather_data/AZO_2022_Aug.csv
# Processing AZO_2022_Jul...
# Results saved to ./cleaned_weather_data/AZO_2022_Jul.csv
# Processing AZO_2022_Jun...
# Results saved to ./cleaned_weather_data/AZO_2022_Jun.csv
# Processing AZO_2022_May...
# Results saved to ./cleaned_weather_data/AZO_2022_May.csv
# Processing AZO_2023_Aug...
# Results saved to ./cleaned_weather_data/AZO_2023_Aug.csv
# Processing AZO_2023_Jul...
# Results saved to ./cleaned_weather_data/AZO_2023_Jul.csv
# Processing AZO_2023_Jun...
# Results saved to ./cleaned_weather_data/AZO_2023_Jun.csv
# Processing AZO_2023_May...
# Results saved to ./cleaned_weather_data/AZO_2023_May.csv
# Processing AZO_2024_Aug...
# Results saved to ./cleaned_weather_data/AZO_2024_Aug.csv
# Processing AZO_2024_Jul...
# Results saved to ./cleaned_weather_data/AZO_2024_Jul.csv
# Processing AZO_2024_Jun...
# Results saved to ./cleaned_weather_data/AZO_2024_Jun.csv
# Processing AZO_2024_May...
# Results saved to ./cleaned_weather_data/AZO_2024_May.csv
# Processing BET_2021_Aug...
# Results saved to ./cleaned_weather_data/BET_2021_Aug.csv
# Processing BET_2021_Jul...
# Results saved to ./cleaned_weather_data/BET_2021_Jul.csv
# Processing BET_2021_Jun...
# Results saved to ./cleaned_weather_data/BET_2021_Jun.csv
# Processing BET_2021_May...
# Results saved to ./cleaned_weather_data/BET_2021_May.csv
# Processing BET_2022_Aug...
# Results saved to ./cleaned_weather_data/BET_2022_Aug.csv
# Processing BET_2022_Jul...
# Results saved to ./cleaned_weather_data/BET_2022_Jul.csv
# Processing BET_2022_Jun...
# Results saved to ./cleaned_weather_data/BET_2022_Jun.csv
# Processing BET_2022_May...
# Results saved to ./cleaned_weather_data/BET_2022_May.csv
# Processing BET_2023_Aug...
# Results saved to ./cleaned_weather_data/BET_2023_Aug.csv
# Processing BET_2023_Jul...
# Results saved to ./cleaned_weather_data/BET_2023_Jul.csv
# Processing BET_2023_Jun...
# Results saved to ./cleaned_weather_data/BET_2023_Jun.csv
# Processing BET_2023_May...
# Results saved to ./cleaned_weather_data/BET_2023_May.csv
# Processing BET_2024_Aug...
# Results saved to ./cleaned_weather_data/BET_2024_Aug.csv
# Processing BET_2024_Jul...
# Results saved to ./cleaned_weather_data/BET_2024_Jul.csv
# Processing BET_2024_Jun...
# Results saved to ./cleaned_weather_data/BET_2024_Jun.csv
# Processing BET_2024_May...
# Results saved to ./cleaned_weather_data/BET_2024_May.csv
# Processing BFF_2021_Aug...
# Results saved to ./cleaned_weather_data/BFF_2021_Aug.csv
# Processing BFF_2021_Jul...
# Results saved to ./cleaned_weather_data/BFF_2021_Jul.csv
# Processing BFF_2021_Jun...
# Results saved to ./cleaned_weather_data/BFF_2021_Jun.csv
# Processing BFF_2021_May...
# Results saved to ./cleaned_weather_data/BFF_2021_May.csv
# Processing BFF_2022_Aug...
# Results saved to ./cleaned_weather_data/BFF_2022_Aug.csv
# Processing BFF_2022_Jul...
# Results saved to ./cleaned_weather_data/BFF_2022_Jul.csv
# Processing BFF_2022_Jun...
# Results saved to ./cleaned_weather_data/BFF_2022_Jun.csv
# Processing BFF_2022_May...
# Results saved to ./cleaned_weather_data/BFF_2022_May.csv
# Processing BFF_2023_Aug...
# Results saved to ./cleaned_weather_data/BFF_2023_Aug.csv
# Processing BFF_2023_Jul...
# Results saved to ./cleaned_weather_data/BFF_2023_Jul.csv
# Processing BFF_2023_Jun...
# Results saved to ./cleaned_weather_data/BFF_2023_Jun.csv
# Processing BFF_2023_May...
# Results saved to ./cleaned_weather_data/BFF_2023_May.csv
# Processing BFF_2024_Aug...
# Results saved to ./cleaned_weather_data/BFF_2024_Aug.csv
# Processing BFF_2024_Jul...
# Results saved to ./cleaned_weather_data/BFF_2024_Jul.csv
# Processing BFF_2024_Jun...
# Results saved to ./cleaned_weather_data/BFF_2024_Jun.csv
# Processing BFF_2024_May...
# Results saved to ./cleaned_weather_data/BFF_2024_May.csv
# Processing BFL_2021_Aug...
# Results saved to ./cleaned_weather_data/BFL_2021_Aug.csv
# Processing BFL_2021_Jul...
# Results saved to ./cleaned_weather_data/BFL_2021_Jul.csv
# Processing BFL_2021_Jun...
# Results saved to ./cleaned_weather_data/BFL_2021_Jun.csv
# Processing BFL_2021_May...
# Results saved to ./cleaned_weather_data/BFL_2021_May.csv
# Processing BFL_2022_Aug...
# Results saved to ./cleaned_weather_data/BFL_2022_Aug.csv
# Processing BFL_2022_Jul...
# Results saved to ./cleaned_weather_data/BFL_2022_Jul.csv
# Processing BFL_2022_Jun...
# Results saved to ./cleaned_weather_data/BFL_2022_Jun.csv
# Processing BFL_2022_May...
# Results saved to ./cleaned_weather_data/BFL_2022_May.csv
# Processing BFL_2023_Aug...
# Results saved to ./cleaned_weather_data/BFL_2023_Aug.csv
# Processing BFL_2023_Jul...
# Results saved to ./cleaned_weather_data/BFL_2023_Jul.csv
# Processing BFL_2023_Jun...
# Results saved to ./cleaned_weather_data/BFL_2023_Jun.csv
# Processing BFL_2023_May...
# Results saved to ./cleaned_weather_data/BFL_2023_May.csv
# Processing BFL_2024_Aug...
# Results saved to ./cleaned_weather_data/BFL_2024_Aug.csv
# Processing BFL_2024_Jul...
# Results saved to ./cleaned_weather_data/BFL_2024_Jul.csv
# Processing BFL_2024_Jun...
# Results saved to ./cleaned_weather_data/BFL_2024_Jun.csv
# Processing BFL_2024_May...
# Results saved to ./cleaned_weather_data/BFL_2024_May.csv
# Processing BGR_2021_Aug...
# Results saved to ./cleaned_weather_data/BGR_2021_Aug.csv
# Processing BGR_2021_Jul...
# Results saved to ./cleaned_weather_data/BGR_2021_Jul.csv
# Processing BGR_2021_Jun...
# Results saved to ./cleaned_weather_data/BGR_2021_Jun.csv
# Processing BGR_2021_May...
# Results saved to ./cleaned_weather_data/BGR_2021_May.csv
# Processing BGR_2022_Aug...
# Results saved to ./cleaned_weather_data/BGR_2022_Aug.csv
# Processing BGR_2022_Jul...
# Results saved to ./cleaned_weather_data/BGR_2022_Jul.csv
# Processing BGR_2022_Jun...
# Results saved to ./cleaned_weather_data/BGR_2022_Jun.csv
# Processing BGR_2022_May...
# Results saved to ./cleaned_weather_data/BGR_2022_May.csv
# Processing BGR_2023_Aug...
# Results saved to ./cleaned_weather_data/BGR_2023_Aug.csv
# Processing BGR_2023_Jul...
# Results saved to ./cleaned_weather_data/BGR_2023_Jul.csv
# Processing BGR_2023_Jun...
# Results saved to ./cleaned_weather_data/BGR_2023_Jun.csv
# Processing BGR_2023_May...
# Results saved to ./cleaned_weather_data/BGR_2023_May.csv
# Processing BGR_2024_Aug...
# Results saved to ./cleaned_weather_data/BGR_2024_Aug.csv
# Processing BGR_2024_Jul...
# Results saved to ./cleaned_weather_data/BGR_2024_Jul.csv
# Processing BGR_2024_Jun...
# Results saved to ./cleaned_weather_data/BGR_2024_Jun.csv
# Processing BGR_2024_May...
# Results saved to ./cleaned_weather_data/BGR_2024_May.csv
# Processing BHM_2021_Aug...
# Results saved to ./cleaned_weather_data/BHM_2021_Aug.csv
# Processing BHM_2021_Jul...
# Results saved to ./cleaned_weather_data/BHM_2021_Jul.csv
# Processing BHM_2021_Jun...
# Results saved to ./cleaned_weather_data/BHM_2021_Jun.csv
# Processing BHM_2021_May...
# Results saved to ./cleaned_weather_data/BHM_2021_May.csv
# Processing BHM_2022_Aug...
# Results saved to ./cleaned_weather_data/BHM_2022_Aug.csv
# Processing BHM_2022_Jul...
# Results saved to ./cleaned_weather_data/BHM_2022_Jul.csv
# Processing BHM_2022_Jun...
# Results saved to ./cleaned_weather_data/BHM_2022_Jun.csv
# Processing BHM_2022_May...
# Results saved to ./cleaned_weather_data/BHM_2022_May.csv
# Processing BHM_2023_Aug...
# Results saved to ./cleaned_weather_data/BHM_2023_Aug.csv
# Processing BHM_2023_Jul...
# Results saved to ./cleaned_weather_data/BHM_2023_Jul.csv
# Processing BHM_2023_Jun...
# Results saved to ./cleaned_weather_data/BHM_2023_Jun.csv
# Processing BHM_2023_May...
# Results saved to ./cleaned_weather_data/BHM_2023_May.csv
# Processing BHM_2024_Aug...
# Results saved to ./cleaned_weather_data/BHM_2024_Aug.csv
# Processing BHM_2024_Jul...
# Results saved to ./cleaned_weather_data/BHM_2024_Jul.csv
# Processing BHM_2024_Jun...
# Results saved to ./cleaned_weather_data/BHM_2024_Jun.csv
# Processing BHM_2024_May...
# Results saved to ./cleaned_weather_data/BHM_2024_May.csv
# Processing BIH_2021_Aug...
# Results saved to ./cleaned_weather_data/BIH_2021_Aug.csv
# Processing BIH_2021_Jul...
# Results saved to ./cleaned_weather_data/BIH_2021_Jul.csv
# Processing BIH_2021_Jun...
# Results saved to ./cleaned_weather_data/BIH_2021_Jun.csv
# Processing BIH_2021_May...
# Results saved to ./cleaned_weather_data/BIH_2021_May.csv
# Processing BIH_2022_Aug...
# Results saved to ./cleaned_weather_data/BIH_2022_Aug.csv
# Processing BIH_2022_Jul...
# Results saved to ./cleaned_weather_data/BIH_2022_Jul.csv
# Processing BIH_2022_Jun...
# Results saved to ./cleaned_weather_data/BIH_2022_Jun.csv
# Processing BIH_2022_May...
# Results saved to ./cleaned_weather_data/BIH_2022_May.csv
# Processing BIH_2023_Aug...
# Results saved to ./cleaned_weather_data/BIH_2023_Aug.csv
# Processing BIH_2023_Jul...
# Results saved to ./cleaned_weather_data/BIH_2023_Jul.csv
# Processing BIH_2023_Jun...
# Results saved to ./cleaned_weather_data/BIH_2023_Jun.csv
# Processing BIH_2023_May...
# Results saved to ./cleaned_weather_data/BIH_2023_May.csv
# Processing BIH_2024_Aug...
# Results saved to ./cleaned_weather_data/BIH_2024_Aug.csv
# Processing BIH_2024_Jul...
# Results saved to ./cleaned_weather_data/BIH_2024_Jul.csv
# Processing BIH_2024_Jun...
# Results saved to ./cleaned_weather_data/BIH_2024_Jun.csv
# Processing BIH_2024_May...
# Results saved to ./cleaned_weather_data/BIH_2024_May.csv
# Processing BIL_2021_Aug...
# Results saved to ./cleaned_weather_data/BIL_2021_Aug.csv
# Processing BIL_2021_Jul...
# Results saved to ./cleaned_weather_data/BIL_2021_Jul.csv
# Processing BIL_2021_Jun...
# Results saved to ./cleaned_weather_data/BIL_2021_Jun.csv
# Processing BIL_2021_May...
# Results saved to ./cleaned_weather_data/BIL_2021_May.csv
# Processing BIL_2022_Aug...
# Results saved to ./cleaned_weather_data/BIL_2022_Aug.csv
# Processing BIL_2022_Jul...
# Results saved to ./cleaned_weather_data/BIL_2022_Jul.csv
# Processing BIL_2022_Jun...
# Results saved to ./cleaned_weather_data/BIL_2022_Jun.csv
# Processing BIL_2022_May...
# Results saved to ./cleaned_weather_data/BIL_2022_May.csv
# Processing BIL_2023_Aug...
# Results saved to ./cleaned_weather_data/BIL_2023_Aug.csv
# Processing BIL_2023_Jul...
# Results saved to ./cleaned_weather_data/BIL_2023_Jul.csv
# Processing BIL_2023_Jun...
# Results saved to ./cleaned_weather_data/BIL_2023_Jun.csv
# Processing BIL_2023_May...
# Results saved to ./cleaned_weather_data/BIL_2023_May.csv
# Processing BIL_2024_Aug...
# Results saved to ./cleaned_weather_data/BIL_2024_Aug.csv
# Processing BIL_2024_Jul...
# Results saved to ./cleaned_weather_data/BIL_2024_Jul.csv
# Processing BIL_2024_Jun...
# Results saved to ./cleaned_weather_data/BIL_2024_Jun.csv
# Processing BIL_2024_May...
# Results saved to ./cleaned_weather_data/BIL_2024_May.csv
# Processing BLI_2021_Aug...
# Results saved to ./cleaned_weather_data/BLI_2021_Aug.csv
# Processing BLI_2021_Jul...
# Results saved to ./cleaned_weather_data/BLI_2021_Jul.csv
# Processing BLI_2021_Jun...
# Results saved to ./cleaned_weather_data/BLI_2021_Jun.csv
# Processing BLI_2021_May...
# Results saved to ./cleaned_weather_data/BLI_2021_May.csv
# Processing BLI_2022_Aug...
# Results saved to ./cleaned_weather_data/BLI_2022_Aug.csv
# Processing BLI_2022_Jul...
# Results saved to ./cleaned_weather_data/BLI_2022_Jul.csv
# Processing BLI_2022_Jun...
# Results saved to ./cleaned_weather_data/BLI_2022_Jun.csv
# Processing BLI_2022_May...
# Results saved to ./cleaned_weather_data/BLI_2022_May.csv
# Processing BLI_2023_Aug...
# Results saved to ./cleaned_weather_data/BLI_2023_Aug.csv
# Processing BLI_2023_Jul...
# Results saved to ./cleaned_weather_data/BLI_2023_Jul.csv
# Processing BLI_2023_Jun...
# Results saved to ./cleaned_weather_data/BLI_2023_Jun.csv
# Processing BLI_2023_May...
# Results saved to ./cleaned_weather_data/BLI_2023_May.csv
# Processing BLI_2024_Aug...
# Results saved to ./cleaned_weather_data/BLI_2024_Aug.csv
# Processing BLI_2024_Jul...
# Results saved to ./cleaned_weather_data/BLI_2024_Jul.csv
# Processing BLI_2024_Jun...
# Results saved to ./cleaned_weather_data/BLI_2024_Jun.csv
# Processing BLI_2024_May...
# Results saved to ./cleaned_weather_data/BLI_2024_May.csv
# Processing BNA_2021_Aug...
# Results saved to ./cleaned_weather_data/BNA_2021_Aug.csv
# Processing BNA_2021_Jul...
# Results saved to ./cleaned_weather_data/BNA_2021_Jul.csv
# Processing BNA_2021_Jun...
# Results saved to ./cleaned_weather_data/BNA_2021_Jun.csv
# Processing BNA_2021_May...
# Results saved to ./cleaned_weather_data/BNA_2021_May.csv
# Processing BNA_2022_Aug...
# Results saved to ./cleaned_weather_data/BNA_2022_Aug.csv
# Processing BNA_2022_Jul...
# Results saved to ./cleaned_weather_data/BNA_2022_Jul.csv
# Processing BNA_2022_Jun...
# Results saved to ./cleaned_weather_data/BNA_2022_Jun.csv
# Processing BNA_2022_May...
# Results saved to ./cleaned_weather_data/BNA_2022_May.csv
# Processing BNA_2023_Aug...
# Results saved to ./cleaned_weather_data/BNA_2023_Aug.csv
# Processing BNA_2023_Jul...
# Results saved to ./cleaned_weather_data/BNA_2023_Jul.csv
# Processing BNA_2023_Jun...
# Results saved to ./cleaned_weather_data/BNA_2023_Jun.csv
# Processing BNA_2023_May...
# Results saved to ./cleaned_weather_data/BNA_2023_May.csv
# Processing BNA_2024_Aug...
# Results saved to ./cleaned_weather_data/BNA_2024_Aug.csv
# Processing BNA_2024_Jul...
# Results saved to ./cleaned_weather_data/BNA_2024_Jul.csv
# Processing BNA_2024_Jun...
# Results saved to ./cleaned_weather_data/BNA_2024_Jun.csv
# Processing BNA_2024_May...
# Results saved to ./cleaned_weather_data/BNA_2024_May.csv
# Processing BRD_2021_Aug...
# Results saved to ./cleaned_weather_data/BRD_2021_Aug.csv
# Processing BRD_2021_Jul...
# Results saved to ./cleaned_weather_data/BRD_2021_Jul.csv
# Processing BRD_2021_Jun...
# Results saved to ./cleaned_weather_data/BRD_2021_Jun.csv
# Processing BRD_2021_May...
# Results saved to ./cleaned_weather_data/BRD_2021_May.csv
# Processing BRD_2022_Aug...
# Results saved to ./cleaned_weather_data/BRD_2022_Aug.csv
# Processing BRD_2022_Jul...
# Results saved to ./cleaned_weather_data/BRD_2022_Jul.csv
# Processing BRD_2022_Jun...
# Results saved to ./cleaned_weather_data/BRD_2022_Jun.csv
# Processing BRD_2022_May...
# Results saved to ./cleaned_weather_data/BRD_2022_May.csv
# Processing BRD_2023_Aug...
# Results saved to ./cleaned_weather_data/BRD_2023_Aug.csv
# Processing BRD_2023_Jul...
# Results saved to ./cleaned_weather_data/BRD_2023_Jul.csv
# Processing BRD_2023_Jun...
# Results saved to ./cleaned_weather_data/BRD_2023_Jun.csv
# Processing BRD_2023_May...
# Results saved to ./cleaned_weather_data/BRD_2023_May.csv
# Processing BRD_2024_Aug...
# Results saved to ./cleaned_weather_data/BRD_2024_Aug.csv
# Processing BRD_2024_Jul...
# Results saved to ./cleaned_weather_data/BRD_2024_Jul.csv
# Processing BRD_2024_Jun...
# Results saved to ./cleaned_weather_data/BRD_2024_Jun.csv
# Processing BRD_2024_May...
# Results saved to ./cleaned_weather_data/BRD_2024_May.csv
# Processing BRW_2021_Aug...
# Results saved to ./cleaned_weather_data/BRW_2021_Aug.csv
# Processing BRW_2021_Jul...
# Results saved to ./cleaned_weather_data/BRW_2021_Jul.csv
# Processing BRW_2021_Jun...
# Results saved to ./cleaned_weather_data/BRW_2021_Jun.csv
# Processing BRW_2021_May...
# Results saved to ./cleaned_weather_data/BRW_2021_May.csv
# Processing BRW_2022_Aug...
# Results saved to ./cleaned_weather_data/BRW_2022_Aug.csv
# Processing BRW_2022_Jul...
# Results saved to ./cleaned_weather_data/BRW_2022_Jul.csv
# Processing BRW_2022_Jun...
# Results saved to ./cleaned_weather_data/BRW_2022_Jun.csv
# Processing BRW_2022_May...
# Results saved to ./cleaned_weather_data/BRW_2022_May.csv
# Processing BRW_2023_Aug...
# Results saved to ./cleaned_weather_data/BRW_2023_Aug.csv
# Processing BRW_2023_Jul...
# Results saved to ./cleaned_weather_data/BRW_2023_Jul.csv
# Processing BRW_2023_Jun...
# Results saved to ./cleaned_weather_data/BRW_2023_Jun.csv
# Processing BRW_2023_May...
# Results saved to ./cleaned_weather_data/BRW_2023_May.csv
# Processing BRW_2024_Aug...
# Results saved to ./cleaned_weather_data/BRW_2024_Aug.csv
# Processing BRW_2024_Jul...
# Results saved to ./cleaned_weather_data/BRW_2024_Jul.csv
# Processing BRW_2024_Jun...
# Results saved to ./cleaned_weather_data/BRW_2024_Jun.csv
# Processing BRW_2024_May...
# Results saved to ./cleaned_weather_data/BRW_2024_May.csv
# Processing BTM_2021_Aug...
# Results saved to ./cleaned_weather_data/BTM_2021_Aug.csv
# Processing BTM_2021_Jul...
# Results saved to ./cleaned_weather_data/BTM_2021_Jul.csv
# Processing BTM_2021_Jun...
# Results saved to ./cleaned_weather_data/BTM_2021_Jun.csv
# Processing BTM_2021_May...
# Results saved to ./cleaned_weather_data/BTM_2021_May.csv
# Processing BTM_2022_Aug...
# Results saved to ./cleaned_weather_data/BTM_2022_Aug.csv
# Processing BTM_2022_Jul...
# Results saved to ./cleaned_weather_data/BTM_2022_Jul.csv
# Processing BTM_2022_Jun...
# Results saved to ./cleaned_weather_data/BTM_2022_Jun.csv
# Processing BTM_2022_May...
# Results saved to ./cleaned_weather_data/BTM_2022_May.csv
# Processing BTM_2023_Aug...
# Results saved to ./cleaned_weather_data/BTM_2023_Aug.csv
# Processing BTM_2023_Jul...
# Results saved to ./cleaned_weather_data/BTM_2023_Jul.csv
# Processing BTM_2023_Jun...
# Results saved to ./cleaned_weather_data/BTM_2023_Jun.csv
# Processing BTM_2023_May...
# Results saved to ./cleaned_weather_data/BTM_2023_May.csv
# Processing BTM_2024_Aug...
# Results saved to ./cleaned_weather_data/BTM_2024_Aug.csv
# Processing BTM_2024_Jul...
# ...
# Processing TOL_2021_Jun...
# Results saved to ./cleaned_weather_data/TOL_2021_Jun.csv
# Processing TOL_2021_May...
# Results saved to ./cleaned_weather_data/TOL_2021_May.csv
# Processing TOL_2022_Aug...
# Results saved to ./cleaned_weather_data/TOL_2022_Aug.csv
# Processing TOL_2022_Jul...
# Results saved to ./cleaned_weather_data/TOL_2022_Jul.csv
# Processing TOL_2022_Jun...
# Results saved to ./cleaned_weather_data/TOL_2022_Jun.csv
# Processing TOL_2022_May...
# Results saved to ./cleaned_weather_data/TOL_2022_May.csv
# Processing TOL_2023_Aug...
# Results saved to ./cleaned_weather_data/TOL_2023_Aug.csv
# Processing TOL_2023_Jul...
# Results saved to ./cleaned_weather_data/TOL_2023_Jul.csv
# Processing TOL_2023_Jun...
# Results saved to ./cleaned_weather_data/TOL_2023_Jun.csv
# Processing TOL_2023_May...
# Results saved to ./cleaned_weather_data/TOL_2023_May.csv
# Processing TOL_2024_Aug...
# Results saved to ./cleaned_weather_data/TOL_2024_Aug.csv
# Processing TOL_2024_Jul...
# Results saved to ./cleaned_weather_data/TOL_2024_Jul.csv
# Processing TOL_2024_Jun...
# Results saved to ./cleaned_weather_data/TOL_2024_Jun.csv
# Processing TOL_2024_May...
# Results saved to ./cleaned_weather_data/TOL_2024_May.csv
# Processing TPA_2021_Aug...
# Results saved to ./cleaned_weather_data/TPA_2021_Aug.csv
# Processing TPA_2021_Jul...
# Results saved to ./cleaned_weather_data/TPA_2021_Jul.csv
# Processing TPA_2021_Jun...
# Results saved to ./cleaned_weather_data/TPA_2021_Jun.csv
# Processing TPA_2021_May...
# Results saved to ./cleaned_weather_data/TPA_2021_May.csv
# Processing TPA_2022_Aug...
# Results saved to ./cleaned_weather_data/TPA_2022_Aug.csv
# Processing TPA_2022_Jul...
# Results saved to ./cleaned_weather_data/TPA_2022_Jul.csv
# Processing TPA_2022_Jun...
# Results saved to ./cleaned_weather_data/TPA_2022_Jun.csv
# Processing TPA_2022_May...
# Results saved to ./cleaned_weather_data/TPA_2022_May.csv
# Processing TPA_2023_Aug...
# Results saved to ./cleaned_weather_data/TPA_2023_Aug.csv
# Processing TPA_2023_Jul...
# Results saved to ./cleaned_weather_data/TPA_2023_Jul.csv
# Processing TPA_2023_Jun...
# Results saved to ./cleaned_weather_data/TPA_2023_Jun.csv
# Processing TPA_2023_May...
# Results saved to ./cleaned_weather_data/TPA_2023_May.csv
# Processing TPA_2024_Aug...
# Results saved to ./cleaned_weather_data/TPA_2024_Aug.csv
# Processing TPA_2024_Jul...
# Results saved to ./cleaned_weather_data/TPA_2024_Jul.csv
# Processing TPA_2024_Jun...
# Results saved to ./cleaned_weather_data/TPA_2024_Jun.csv
# Processing TPA_2024_May...
# Results saved to ./cleaned_weather_data/TPA_2024_May.csv
# Processing TUL_2021_Aug...
# Results saved to ./cleaned_weather_data/TUL_2021_Aug.csv
# Processing TUL_2021_Jul...
# Results saved to ./cleaned_weather_data/TUL_2021_Jul.csv
# Processing TUL_2021_Jun...
# Results saved to ./cleaned_weather_data/TUL_2021_Jun.csv
# Processing TUL_2021_May...
# Results saved to ./cleaned_weather_data/TUL_2021_May.csv
# Processing TUL_2022_Aug...
# Results saved to ./cleaned_weather_data/TUL_2022_Aug.csv
# Processing TUL_2022_Jul...
# Results saved to ./cleaned_weather_data/TUL_2022_Jul.csv
# Processing TUL_2022_Jun...
# Results saved to ./cleaned_weather_data/TUL_2022_Jun.csv
# Processing TUL_2022_May...
# Results saved to ./cleaned_weather_data/TUL_2022_May.csv
# Processing TUL_2023_Aug...
# Results saved to ./cleaned_weather_data/TUL_2023_Aug.csv
# Processing TUL_2023_Jul...
# Results saved to ./cleaned_weather_data/TUL_2023_Jul.csv
# Processing TUL_2023_Jun...
# Results saved to ./cleaned_weather_data/TUL_2023_Jun.csv
# Processing TUL_2023_May...
# Results saved to ./cleaned_weather_data/TUL_2023_May.csv
# Processing TUL_2024_Aug...
# Results saved to ./cleaned_weather_data/TUL_2024_Aug.csv
# Processing TUL_2024_Jul...
# Results saved to ./cleaned_weather_data/TUL_2024_Jul.csv
# Processing TUL_2024_Jun...
# Results saved to ./cleaned_weather_data/TUL_2024_Jun.csv
# Processing TUL_2024_May...
# Results saved to ./cleaned_weather_data/TUL_2024_May.csv
# Processing TUS_2021_Aug...
# Results saved to ./cleaned_weather_data/TUS_2021_Aug.csv
# Processing TUS_2021_Jul...
# Results saved to ./cleaned_weather_data/TUS_2021_Jul.csv
# Processing TUS_2021_Jun...
# Results saved to ./cleaned_weather_data/TUS_2021_Jun.csv
# Processing TUS_2021_May...
# Results saved to ./cleaned_weather_data/TUS_2021_May.csv
# Processing TUS_2022_Aug...
# Results saved to ./cleaned_weather_data/TUS_2022_Aug.csv
# Processing TUS_2022_Jul...
# Results saved to ./cleaned_weather_data/TUS_2022_Jul.csv
# Processing TUS_2022_Jun...
# Results saved to ./cleaned_weather_data/TUS_2022_Jun.csv
# Processing TUS_2022_May...
# Results saved to ./cleaned_weather_data/TUS_2022_May.csv
# Processing TUS_2023_Aug...
# Results saved to ./cleaned_weather_data/TUS_2023_Aug.csv
# Processing TUS_2023_Jul...
# Results saved to ./cleaned_weather_data/TUS_2023_Jul.csv
# Processing TUS_2023_Jun...
# Results saved to ./cleaned_weather_data/TUS_2023_Jun.csv
# Processing TUS_2023_May...
# Results saved to ./cleaned_weather_data/TUS_2023_May.csv
# Processing TUS_2024_Aug...
# Results saved to ./cleaned_weather_data/TUS_2024_Aug.csv
# Processing TUS_2024_Jul...
# Results saved to ./cleaned_weather_data/TUS_2024_Jul.csv
# Processing TUS_2024_Jun...
# Results saved to ./cleaned_weather_data/TUS_2024_Jun.csv
# Processing TUS_2024_May...
# Results saved to ./cleaned_weather_data/TUS_2024_May.csv
# Processing TVC_2021_Aug...
# Results saved to ./cleaned_weather_data/TVC_2021_Aug.csv
# Processing TVC_2021_Jul...
# Results saved to ./cleaned_weather_data/TVC_2021_Jul.csv
# Processing TVC_2021_Jun...
# Results saved to ./cleaned_weather_data/TVC_2021_Jun.csv
# Processing TVC_2021_May...
# Results saved to ./cleaned_weather_data/TVC_2021_May.csv
# Processing TVC_2022_Aug...
# Results saved to ./cleaned_weather_data/TVC_2022_Aug.csv
# Processing TVC_2022_Jul...
# Results saved to ./cleaned_weather_data/TVC_2022_Jul.csv
# Processing TVC_2022_Jun...
# Results saved to ./cleaned_weather_data/TVC_2022_Jun.csv
# Processing TVC_2022_May...
# Results saved to ./cleaned_weather_data/TVC_2022_May.csv
# Processing TVC_2023_Aug...
# Results saved to ./cleaned_weather_data/TVC_2023_Aug.csv
# Processing TVC_2023_Jul...
# Results saved to ./cleaned_weather_data/TVC_2023_Jul.csv
# Processing TVC_2023_Jun...
# Results saved to ./cleaned_weather_data/TVC_2023_Jun.csv
# Processing TVC_2023_May...
# Results saved to ./cleaned_weather_data/TVC_2023_May.csv
# Processing TVC_2024_Aug...
# Results saved to ./cleaned_weather_data/TVC_2024_Aug.csv
# Processing TVC_2024_Jul...
# Results saved to ./cleaned_weather_data/TVC_2024_Jul.csv
# Processing TVC_2024_Jun...
# Results saved to ./cleaned_weather_data/TVC_2024_Jun.csv
# Processing TVC_2024_May...
# Results saved to ./cleaned_weather_data/TVC_2024_May.csv
# Processing TWF_2021_Aug...
# Results saved to ./cleaned_weather_data/TWF_2021_Aug.csv
# Processing TWF_2021_Jul...
# Results saved to ./cleaned_weather_data/TWF_2021_Jul.csv
# Processing TWF_2021_Jun...
# Results saved to ./cleaned_weather_data/TWF_2021_Jun.csv
# Processing TWF_2021_May...
# Results saved to ./cleaned_weather_data/TWF_2021_May.csv
# Processing TWF_2022_Aug...
# Results saved to ./cleaned_weather_data/TWF_2022_Aug.csv
# Processing TWF_2022_Jul...
# Results saved to ./cleaned_weather_data/TWF_2022_Jul.csv
# Processing TWF_2022_Jun...
# Results saved to ./cleaned_weather_data/TWF_2022_Jun.csv
# Processing TWF_2022_May...
# Results saved to ./cleaned_weather_data/TWF_2022_May.csv
# Processing TWF_2023_Aug...
# Results saved to ./cleaned_weather_data/TWF_2023_Aug.csv
# Processing TWF_2023_Jul...
# Results saved to ./cleaned_weather_data/TWF_2023_Jul.csv
# Processing TWF_2023_Jun...
# Results saved to ./cleaned_weather_data/TWF_2023_Jun.csv
# Processing TWF_2023_May...
# Results saved to ./cleaned_weather_data/TWF_2023_May.csv
# Processing TWF_2024_Aug...
# Results saved to ./cleaned_weather_data/TWF_2024_Aug.csv
# Processing TWF_2024_Jul...
# Results saved to ./cleaned_weather_data/TWF_2024_Jul.csv
# Processing TWF_2024_Jun...
# Results saved to ./cleaned_weather_data/TWF_2024_Jun.csv
# Processing TWF_2024_May...
# Results saved to ./cleaned_weather_data/TWF_2024_May.csv
# Processing TYS_2021_Aug...
# Results saved to ./cleaned_weather_data/TYS_2021_Aug.csv
# Processing TYS_2021_Jul...
# Results saved to ./cleaned_weather_data/TYS_2021_Jul.csv
# Processing TYS_2021_Jun...
# Results saved to ./cleaned_weather_data/TYS_2021_Jun.csv
# Processing TYS_2021_May...
# Results saved to ./cleaned_weather_data/TYS_2021_May.csv
# Processing TYS_2022_Aug...
# Results saved to ./cleaned_weather_data/TYS_2022_Aug.csv
# Processing TYS_2022_Jul...
# Results saved to ./cleaned_weather_data/TYS_2022_Jul.csv
# Processing TYS_2022_Jun...
# Results saved to ./cleaned_weather_data/TYS_2022_Jun.csv
# Processing TYS_2022_May...
# Results saved to ./cleaned_weather_data/TYS_2022_May.csv
# Processing TYS_2023_Aug...
# Results saved to ./cleaned_weather_data/TYS_2023_Aug.csv
# Processing TYS_2023_Jul...
# Results saved to ./cleaned_weather_data/TYS_2023_Jul.csv
# Processing TYS_2023_Jun...
# Results saved to ./cleaned_weather_data/TYS_2023_Jun.csv
# Processing TYS_2023_May...
# Results saved to ./cleaned_weather_data/TYS_2023_May.csv
# Processing TYS_2024_Aug...
# Results saved to ./cleaned_weather_data/TYS_2024_Aug.csv
# Processing TYS_2024_Jul...
# Results saved to ./cleaned_weather_data/TYS_2024_Jul.csv
# Processing TYS_2024_Jun...
# Results saved to ./cleaned_weather_data/TYS_2024_Jun.csv
# Processing TYS_2024_May...
# Results saved to ./cleaned_weather_data/TYS_2024_May.csv
# Processing VCT_2021_Aug...
# Results saved to ./cleaned_weather_data/VCT_2021_Aug.csv
# Processing VCT_2021_Jul...
# Results saved to ./cleaned_weather_data/VCT_2021_Jul.csv
# Processing VCT_2021_Jun...
# Results saved to ./cleaned_weather_data/VCT_2021_Jun.csv
# Processing VCT_2021_May...
# Results saved to ./cleaned_weather_data/VCT_2021_May.csv
# Processing VCT_2022_Aug...
# Results saved to ./cleaned_weather_data/VCT_2022_Aug.csv
# Processing VCT_2022_Jul...
# Results saved to ./cleaned_weather_data/VCT_2022_Jul.csv
# Processing VCT_2022_Jun...
# Results saved to ./cleaned_weather_data/VCT_2022_Jun.csv
# Processing VCT_2022_May...
# Results saved to ./cleaned_weather_data/VCT_2022_May.csv
# Processing VCT_2023_Aug...
# Results saved to ./cleaned_weather_data/VCT_2023_Aug.csv
# Processing VCT_2023_Jul...
# Results saved to ./cleaned_weather_data/VCT_2023_Jul.csv
# Processing VCT_2023_Jun...
# Results saved to ./cleaned_weather_data/VCT_2023_Jun.csv
# Processing VCT_2023_May...
# Results saved to ./cleaned_weather_data/VCT_2023_May.csv
# Processing VCT_2024_Aug...
# Results saved to ./cleaned_weather_data/VCT_2024_Aug.csv
# Processing VCT_2024_Jul...
# Results saved to ./cleaned_weather_data/VCT_2024_Jul.csv
# Processing VCT_2024_Jun...
# Results saved to ./cleaned_weather_data/VCT_2024_Jun.csv
# Processing VCT_2024_May...
# Results saved to ./cleaned_weather_data/VCT_2024_May.csv
# Processing VEL_2021_Aug...
# Results saved to ./cleaned_weather_data/VEL_2021_Aug.csv
# Processing VEL_2021_Jul...
# Results saved to ./cleaned_weather_data/VEL_2021_Jul.csv
# Processing VEL_2021_Jun...
# Results saved to ./cleaned_weather_data/VEL_2021_Jun.csv
# Processing VEL_2021_May...
# Results saved to ./cleaned_weather_data/VEL_2021_May.csv
# Processing VEL_2022_Aug...
# Results saved to ./cleaned_weather_data/VEL_2022_Aug.csv
# Processing VEL_2022_Jul...
# Results saved to ./cleaned_weather_data/VEL_2022_Jul.csv
# Processing VEL_2022_Jun...
# Results saved to ./cleaned_weather_data/VEL_2022_Jun.csv
# Processing VEL_2022_May...
# Results saved to ./cleaned_weather_data/VEL_2022_May.csv
# Processing VEL_2023_Aug...
# Results saved to ./cleaned_weather_data/VEL_2023_Aug.csv
# Processing VEL_2023_Jul...
# Results saved to ./cleaned_weather_data/VEL_2023_Jul.csv
# Processing VEL_2023_Jun...
# Results saved to ./cleaned_weather_data/VEL_2023_Jun.csv
# Processing VEL_2023_May...
# Results saved to ./cleaned_weather_data/VEL_2023_May.csv
# Processing VEL_2024_Aug...
# Results saved to ./cleaned_weather_data/VEL_2024_Aug.csv
# Processing VEL_2024_Jul...
# Results saved to ./cleaned_weather_data/VEL_2024_Jul.csv
# Processing VEL_2024_Jun...
# Results saved to ./cleaned_weather_data/VEL_2024_Jun.csv
# Processing VEL_2024_May...
# Results saved to ./cleaned_weather_data/VEL_2024_May.csv
# Processing VLD_2021_Aug...
# Results saved to ./cleaned_weather_data/VLD_2021_Aug.csv
# Processing VLD_2021_Jul...
# Results saved to ./cleaned_weather_data/VLD_2021_Jul.csv
# Processing VLD_2021_Jun...
# Results saved to ./cleaned_weather_data/VLD_2021_Jun.csv
# Processing VLD_2021_May...
# Results saved to ./cleaned_weather_data/VLD_2021_May.csv
# Processing VLD_2022_Aug...
# Results saved to ./cleaned_weather_data/VLD_2022_Aug.csv
# Processing VLD_2022_Jul...
# Results saved to ./cleaned_weather_data/VLD_2022_Jul.csv
# Processing VLD_2022_Jun...
# Results saved to ./cleaned_weather_data/VLD_2022_Jun.csv
# Processing VLD_2022_May...
# Results saved to ./cleaned_weather_data/VLD_2022_May.csv
# Processing VLD_2023_Aug...
# Results saved to ./cleaned_weather_data/VLD_2023_Aug.csv
# Processing VLD_2023_Jul...
# Results saved to ./cleaned_weather_data/VLD_2023_Jul.csv
# Processing VLD_2023_Jun...
# Results saved to ./cleaned_weather_data/VLD_2023_Jun.csv
# Processing VLD_2023_May...
# Results saved to ./cleaned_weather_data/VLD_2023_May.csv
# Processing VLD_2024_Aug...
# Results saved to ./cleaned_weather_data/VLD_2024_Aug.csv
# Processing VLD_2024_Jul...
# Results saved to ./cleaned_weather_data/VLD_2024_Jul.csv
# Processing VLD_2024_Jun...
# Results saved to ./cleaned_weather_data/VLD_2024_Jun.csv
# Processing VLD_2024_May...
# Results saved to ./cleaned_weather_data/VLD_2024_May.csv
# Processing YAK_2021_Aug...
# Results saved to ./cleaned_weather_data/YAK_2021_Aug.csv
# Processing YAK_2021_Jul...
# Results saved to ./cleaned_weather_data/YAK_2021_Jul.csv
# Processing YAK_2021_Jun...
# Results saved to ./cleaned_weather_data/YAK_2021_Jun.csv
# Processing YAK_2021_May...
# Results saved to ./cleaned_weather_data/YAK_2021_May.csv
# Processing YAK_2022_Aug...
# Results saved to ./cleaned_weather_data/YAK_2022_Aug.csv
# Processing YAK_2022_Jul...
# Results saved to ./cleaned_weather_data/YAK_2022_Jul.csv
# Processing YAK_2022_Jun...
# Results saved to ./cleaned_weather_data/YAK_2022_Jun.csv
# Processing YAK_2022_May...
# Results saved to ./cleaned_weather_data/YAK_2022_May.csv
# Processing YAK_2023_Aug...
# Results saved to ./cleaned_weather_data/YAK_2023_Aug.csv
# Processing YAK_2023_Jul...
# Results saved to ./cleaned_weather_data/YAK_2023_Jul.csv
# Processing YAK_2023_Jun...
# Results saved to ./cleaned_weather_data/YAK_2023_Jun.csv
# Processing YAK_2023_May...
# Results saved to ./cleaned_weather_data/YAK_2023_May.csv
# Processing YAK_2024_Aug...
# Results saved to ./cleaned_weather_data/YAK_2024_Aug.csv
# Processing YAK_2024_Jul...
# Results saved to ./cleaned_weather_data/YAK_2024_Jul.csv
# Processing YAK_2024_Jun...
# Results saved to ./cleaned_weather_data/YAK_2024_Jun.csv
# Processing YAK_2024_May...
# Results saved to ./cleaned_weather_data/YAK_2024_May.csv
# Processing YKM_2021_Aug...
# Results saved to ./cleaned_weather_data/YKM_2021_Aug.csv
# Processing YKM_2021_Jul...
# Results saved to ./cleaned_weather_data/YKM_2021_Jul.csv
# Processing YKM_2021_Jun...
# Results saved to ./cleaned_weather_data/YKM_2021_Jun.csv
# Processing YKM_2021_May...
# Results saved to ./cleaned_weather_data/YKM_2021_May.csv
# Processing YKM_2022_Aug...
# Results saved to ./cleaned_weather_data/YKM_2022_Aug.csv
# Processing YKM_2022_Jul...
# Results saved to ./cleaned_weather_data/YKM_2022_Jul.csv
# Processing YKM_2022_Jun...
# Results saved to ./cleaned_weather_data/YKM_2022_Jun.csv
# Processing YKM_2022_May...
# Results saved to ./cleaned_weather_data/YKM_2022_May.csv
# Processing YKM_2023_Aug...
# Results saved to ./cleaned_weather_data/YKM_2023_Aug.csv
# Processing YKM_2023_Jul...
# Results saved to ./cleaned_weather_data/YKM_2023_Jul.csv
# Processing YKM_2023_Jun...
# Results saved to ./cleaned_weather_data/YKM_2023_Jun.csv
# Processing YKM_2023_May...
# Results saved to ./cleaned_weather_data/YKM_2023_May.csv
# Processing YKM_2024_Aug...
# Results saved to ./cleaned_weather_data/YKM_2024_Aug.csv
# Processing YKM_2024_Jul...
# Results saved to ./cleaned_weather_data/YKM_2024_Jul.csv
# Processing YKM_2024_Jun...
# Results saved to ./cleaned_weather_data/YKM_2024_Jun.csv
# Processing YKM_2024_May...
# Results saved to ./cleaned_weather_data/YKM_2024_May.csv
# Processing complete!

# %%
import pandas as pd
import itertools
import os
import re
from datetime import datetime

# Define data directory
data_dir = "./cleaned_data/"

# Get all data files
data_files = [
    'May2021.csv', 'May2022.csv', 'May2023.csv', 'May2024.csv',
    'June2021.csv', 'June2022.csv', 'June2023.csv', 'June2024.csv',
    'July2021.csv', 'July2022.csv', 'July2023.csv', 'July2024.csv',
    'August2021.csv', 'August2022.csv', 'August2023.csv', 'August2024.csv'
]

# Convert to full paths
data_files_with_path = [os.path.join(data_dir, file) for file in data_files]

# Sort files by date (newest to oldest)
def extract_date(filepath):
    filename = os.path.basename(filepath)
    match = re.match(r'(\w+)(\d{4})\.csv', filename)
    if match:
        month, year = match.groups()
        month_map = {
            'January': 1, 'February': 2, 'March': 3, 'April': 4,
            'May': 5, 'June': 6, 'July': 7, 'August': 8,
            'September': 9, 'October': 10, 'November': 11, 'December': 12
        }
        month_num = month_map.get(month, 0)
        return datetime(int(year), month_num, 1)
    return datetime(1900, 1, 1)  # Default date

# Sort from newest to oldest
sorted_data_files = sorted(data_files_with_path, key=extract_date, reverse=True)

# Read top 30 airports data
top_airports = pd.read_csv('top_100_airports.csv')
top_30_airport_codes = top_airports.head(30)['ORIGIN_IATA'].tolist()

# Create all possible airport pair combinations
airport_pairs = list(itertools.combinations(top_30_airport_codes, 2))

# Create dictionaries to store results
results = {}
data_sources = {}

# Pre-load all data files for efficiency
distance_data_frames = {}
for file in sorted_data_files:
    if os.path.exists(file):
        try:
            distance_data_frames[file] = pd.read_csv(file)
            print(f"Loaded: {file}")
        except Exception as e:
            print(f"Failed to load {file}: {e}")
    else:
        print(f"Warning: File {file} does not exist and will be skipped.")

print(f"Loaded {len(distance_data_frames)} data files.")
print(f"There are {len(airport_pairs)} airport pairs to query.")

# Create progress counter
count = 0
total = len(airport_pairs)

# Iterate through all airport pairs
for origin, dest in airport_pairs:
    count += 1
    if count % 50 == 0:
        print(f"Progress: {count}/{total} ({(count/total*100):.1f}%)")

    found = False

    # Search in each file by priority
    for file, df in distance_data_frames.items():
        # Look for distance from origin to dest
        query1 = df[(df['ORIGIN_IATA'] == origin) & (df['DEST_IATA'] == dest)]

        # Look for distance from dest to origin (reverse)
        query2 = df[(df['ORIGIN_IATA'] == dest) & (df['DEST_IATA'] == origin)]

        # If distance data is found
        if not query1.empty:
            distance = query1['DISTANCE'].values[0]
            results[(origin, dest)] = distance
            data_sources[(origin, dest)] = os.path.basename(file)  # Store filename only
            found = True
            break
        elif not query2.empty:
            distance = query2['DISTANCE'].values[0]
            results[(origin, dest)] = distance
            data_sources[(origin, dest)] = os.path.basename(file)  # Store filename only
            found = True
            break

    # If no data found in any file
    if not found:
        results[(origin, dest)] = None
        data_sources[(origin, dest)] = 'Not Found'

# Convert results to DataFrame
result_df = pd.DataFrame([
    {'Origin': pair[0], 'Destination': pair[1], 'Distance': distance, 'Data_Source': data_sources[pair]}
    for pair, distance in results.items()
])

# Save results
output_path = os.path.join(data_dir, 'top30_airport_distances.csv')
result_df.to_csv(output_path, index=False)
print(f"Results saved to: {output_path}")

# Output statistics
total_pairs = len(airport_pairs)
pairs_with_distance = len([d for d in results.values() if d is not None])

print("\nResult Statistics:")
print(f"Total airport pairs: {total_pairs}")
print(f"Pairs with distance data: {pairs_with_distance} ({pairs_with_distance/total_pairs*100:.1f}%)")
print(f"Pairs missing distance data: {total_pairs - pairs_with_distance} ({(total_pairs-pairs_with_distance)/total_pairs*100:.1f}%)")

# Statistics by data source
source_stats = result_df['Data_Source'].value_counts().to_dict()
print("\nData Source Statistics:")
for source, count in sorted(source_stats.items()):
    print(f"Data from {source}: {count} entries ({count/total_pairs*100:.1f}%)")
# Out:
# Loaded: ./cleaned_data/August2024.csv
# Loaded: ./cleaned_data/July2024.csv
# Loaded: ./cleaned_data/June2024.csv
# Loaded: ./cleaned_data/May2024.csv
# Loaded: ./cleaned_data/August2023.csv
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_25296\1701520018.py:55: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   distance_data_frames[file] = pd.read_csv(file)
# Loaded: ./cleaned_data/July2023.csv
# Loaded: ./cleaned_data/June2023.csv
# Loaded: ./cleaned_data/May2023.csv
# Loaded: ./cleaned_data/August2022.csv
# Loaded: ./cleaned_data/July2022.csv
# Loaded: ./cleaned_data/June2022.csv
# Loaded: ./cleaned_data/May2022.csv
# Loaded: ./cleaned_data/August2021.csv
# Loaded: ./cleaned_data/July2021.csv
# Loaded: ./cleaned_data/June2021.csv
# Loaded: ./cleaned_data/May2021.csv
# Loaded 16 data files.
# There are 435 airport pairs to query.
# Progress: 50/435 (11.5%)
# Progress: 100/435 (23.0%)
# Progress: 150/435 (34.5%)
# Progress: 200/435 (46.0%)
# Progress: 250/435 (57.5%)
# Progress: 300/435 (69.0%)
# Progress: 350/435 (80.5%)
# Progress: 400/435 (92.0%)
# Results saved to: ./cleaned_data/top30_airport_distances.csv
#
# Result Statistics:
# Total airport pairs: 435
# Pairs with distance data: 417 (95.9%)
# Pairs missing distance data: 18 (4.1%)
#
# Data Source Statistics:
# Data from August2023.csv: 2 entries (0.5%)
# Data from August2024.csv: 410 entries (94.3%)
# Data from July2024.csv: 2 entries (0.5%)
# Data from June2022.csv: 1 entries (0.2%)
# Data from June2023.csv: 1 entries (0.2%)
# Data from June2024.csv: 1 entries (0.2%)
# Data from Not Found: 18 entries (4.1%)
